# %%
import os

# Paths
results_path = "output/03_BBO_SHINGLES_DP"
dft_path = os.path.abspath("output/dft_files")

# BBO parameters
period_save = 1
period_compute_test_predictions = 1
max_obj_calls = 1000

# EA parameters
evomol_pop_max_size = 300
evomol_max_steps = 10
evomol_k_to_replace = 10
evomol_init_pop_size = 10
evomol_n_runs = 10
evomol_n_best_retrieved = 1
evomol_init_pop_strategy = "random_weighted"

# Chemical space
max_heavy_atoms = 9
heavy_atoms = "C,N,O,F"

# GPR parameters
gpr_alpha = 1e-1
gpr_optimizer = 'fmin_l_bfgs_b'

# Initial dataset initialization
init_dataset_smiles = ["C"]

# Merit parameters
EI_xi = 0.01

# QM objective and MM optimization
prop = "homo"
MM_program = "rdkit"

# Parallelization (None)
n_jobs_dft = 1
n_jobs_per_model = 1
dft_n_threads = 1

# %%
from sklearn.gaussian_process.kernels import DotProduct

# Kernel
kernel = 1.0*DotProduct(1.0)

# %%
from bbomol.descriptor import ShinglesVectDesc

# Descriptor
descriptor = ShinglesVectDesc(cache_location=None, count=True, vect_size=2000)

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from bbomol.model import GPRSurrogateModelWrapper



# GPR model
surrogate = GPRSurrogateModelWrapper(
    GaussianProcessRegressor(kernel, optimizer=gpr_optimizer, alpha=gpr_alpha)
)

# %%
from bbomol.merit import ExpectedImprovementMerit

# Merit function
merit = ExpectedImprovementMerit(descriptor=descriptor, surrogate=surrogate, xi=EI_xi, pipeline=None)
# Out:
# EI xi : 0.01

# %%
from evomol.evaluation_dft import OPTEvaluationStrategy
from bbomol.objective import EvoMolEvaluationStrategyWrapper

# Objective function
objective = EvoMolEvaluationStrategyWrapper(
        OPTEvaluationStrategy(
            prop=prop,
            n_jobs=dft_n_threads,
            working_dir_path=dft_path,
            MM_program=MM_program,
        ),
        n_jobs=n_jobs_dft
)
# Out:
# 0 molecules in cache

# %%
from os.path import join
from bbomol.bboalg import BBOAlg
from bbomol.stop_criterion import KObjFunCallsFunctionStopCriterion

def run(run_id):
    
    model_path = join(results_path, str(run_id))
    
    alg = BBOAlg(
        init_dataset_smiles=init_dataset_smiles,
        descriptor=descriptor,
        objective=objective,
        merit_function=merit,
        surrogate=surrogate,
        stop_criterion=KObjFunCallsFunctionStopCriterion(max_obj_calls),
        evomol_parameters={
            "optimization_parameters": {
                "pop_max_size": evomol_pop_max_size,
                "max_steps": evomol_max_steps,
                "k_to_replace": evomol_k_to_replace
            },
            "action_space_parameters":{
                "max_heavy_atoms": max_heavy_atoms,
                "atoms": heavy_atoms
            }
        },
        evomol_init_pop_size=evomol_init_pop_size,
        n_evomol_runs=evomol_n_runs,
        n_best_evomol_retrieved=evomol_n_best_retrieved,
        evomol_init_pop_strategy=evomol_init_pop_strategy,
        results_path=model_path,
        n_jobs=n_jobs_per_model,
        period_save=period_save,
        period_compute_test_predictions=period_compute_test_predictions
        
    )
    
    alg.run()

# %%
# Running a single execution

run(0)
# Out:
# Initialization of dataset
# computing dft for C
# Starting OPT
# Execution time OPT: 1s
# There are 5 atoms and 17 MOs
# Initialization of test dataset
# model fitted
# Starting EvoMol optimizations
# run evomol optimization
# SYMBOLS LIST : ['C', 'N', 'O', 'F']
# objective_calls
# Computing scores at initialization...
# Start pop algorithm
# EI_mean : 0.00000
# EI_med : 0.00000
# EI_std : 0.00000
# EI_min : 0.00000
# EI_max : 0.00000
# total_mean : 0.00000
# total_med : 0.00000
# total_std : 0.00000
# total_min : 0.00000
# total_max : 0.00000
# new step
# step : 0
# best : C
# EI_mean : 0.87783
# EI_med : 0.87783
# EI_std : 0.87783
# EI_min : 0.00000
# EI_max : 1.75566
# total_mean : 0.87783
# total_med : 0.87783
# total_std : 0.87783
# total_min : 0.00000
# total_max : 1.75566
# new step
# step : 1
# best : CC
# EI_mean : 0.90929
# EI_med : 0.94074
# EI_std : 0.84754
# EI_min : 0.00000
# EI_max : 1.75566
# total_mean : 0.90929
# total_med : 0.94074
# total_std : 0.84754
# total_min : 0.00000
# total_max : 1.75566
# new step
# step : 2
# best : CC
# EI_mean : 1.02675
# EI_med : 1.24456
# EI_std : 0.76727
# EI_min : 0.00000
# EI_max : 1.96191
# total_mean : 1.02675
# total_med : 1.24456
# total_std : 0.76727
# total_min : 0.00000
# total_max : 1.96191
# new step
# step : 3
# best : CCC
# EI_mean : 1.06585
# EI_med : 1.24456
# EI_std : 0.71705
# EI_min : 0.00000
# EI_max : 1.96191
# total_mean : 1.06585
# total_med : 1.24456
# total_std : 0.71705
# total_min : 0.00000
# total_max : 1.96191
# new step
# step : 4
# best : CCC
# EI_mean : 1.29895
# EI_med : 1.52172
# EI_std : 0.66619
# EI_min : 0.00000
# EI_max : 2.47979
# total_mean : 1.29895
# total_med : 1.52172
# total_std : 0.66619
# total_min : 0.00000
# total_max : 2.47979
# new step
# step : 5
# best : CC#CC
# EI_mean : 1.46604
# EI_med : 1.52172
# EI_std : 0.65486
# EI_min : 0.00000
# EI_max : 2.62986
# total_mean : 1.46604
# total_med : 1.52172
# total_std : 0.65486
# total_min : 0.00000
# total_max : 2.62986
# new step
# step : 6
# best : CC#CCC
# EI_mean : 1.58569
# EI_med : 1.75566
# EI_std : 0.65677
# EI_min : 0.00000
# EI_max : 2.90684
# total_mean : 1.58569
# total_med : 1.75566
# total_std : 0.65677
# total_min : 0.00000
# total_max : 2.90684
# new step
# step : 7
# best : CCC(C)C
# EI_mean : 1.74097
# EI_med : 1.75566
# EI_std : 0.69520
# EI_min : 0.00000
# EI_max : 2.90684
# total_mean : 1.74097
# total_med : 1.75566
# total_std : 0.69520
# total_min : 0.00000
# total_max : 2.90684
# new step
# step : 8
# best : CCC(C)C
# EI_mean : 1.88900
# EI_med : 1.75566
# EI_std : 0.75862
# EI_min : 0.00000
# EI_max : 3.50480
# total_mean : 1.88900
# total_med : 1.75566
# total_std : 0.75862
# total_min : 0.00000
# total_max : 3.50480
# new step
# step : 9
# best : CC#CCCCCO
# EI_mean : 1.97589
# EI_med : 1.96191
# EI_std : 0.75394
# EI_min : 0.00000
# EI_max : 3.50480
# total_mean : 1.97589
# total_med : 1.96191
# total_std : 0.75394
# total_min : 0.00000
# total_max : 3.50480
# Stopping : stop condition reached
# run evomol optimization
# SYMBOLS LIST : ['C', 'N', 'O', 'F']
# objective_calls
# Computing scores at initialization...
# Start pop algorithm
# EI_mean : 0.00000
# EI_med : 0.00000
# EI_std : 0.00000
# EI_min : 0.00000
# EI_max : 0.00000
# total_mean : 0.00000
# total_med : 0.00000
# total_std : 0.00000
# total_min : 0.00000
# total_max : 0.00000
# new step
# step : 0
# best : C
# EI_mean : 0.06291
# EI_med : 0.06291
# EI_std : 0.06291
# EI_min : 0.00000
# EI_max : 0.12583
# total_mean : 0.06291
# total_med : 0.06291
# total_std : 0.06291
# total_min : 0.00000
# total_max : 0.12583
# new step
# step : 1
# best :
# EI_mean : 0.37405
# EI_med : 0.12583
# EI_std : 0.50521
# EI_min : 0.00000
# EI_max : 1.24456
# total_mean : 0.37405
# total_med : 0.12583
# total_std : 0.50521
# total_min : 0.00000
# total_max : 1.24456
# new step
# step : 2
# best : CO
# EI_mean : 0.56427
# EI_med : 0.12583
# EI_std : 0.60515
# EI_min : 0.00000
# EI_max : 1.52172
# total_mean : 0.56427
# total_med : 0.12583
# total_std : 0.60515
# total_min : 0.00000
# total_max : 1.52172
# new step
# step : 3
# best : COF
# EI_mean : 0.94988
# EI_med : 1.24456
# EI_std : 0.62460
# EI_min : 0.00000
# EI_max : 1.75566
# total_mean : 0.94988
# total_med : 1.24456
# total_std : 0.62460
# total_min : 0.00000
# total_max : 1.75566
# new step
# step : 4
# best : CCOF
# EI_mean : 1.20496
# EI_med : 1.24456
# EI_std : 0.58461
# EI_min : 0.00000
# EI_max : 1.75566
# total_mean : 1.20496
# total_med : 1.24456
# total_std : 0.58461
# total_min : 0.00000
# total_max : 1.75566
# new step
# step : 5
# best : CCOF
# EI_mean : 1.36225
# EI_med : 1.52172
# EI_std : 0.57279
# EI_min : 0.00000
# EI_max : 2.32004
# total_mean : 1.36225
# total_med : 1.52172
# total_std : 0.57279
# total_min : 0.00000
# total_max : 2.32004
# new step
# step : 6
# best : FOC(F)F
# EI_mean : 1.49401
# EI_med : 1.52172
# EI_std : 0.56727
# EI_min : 0.00000
# EI_max : 2.32004
# total_mean : 1.49401
# total_med : 1.52172
# total_std : 0.56727
# total_min : 0.00000
# total_max : 2.32004
# new step
# step : 7
# best : FOC(F)F
# EI_mean : 1.60807
# EI_med : 1.75566
# EI_std : 0.58557
# EI_min : 0.00000
# EI_max : 2.62986
# total_mean : 1.60807
# total_med : 1.75566
# total_std : 0.58557
# total_min : 0.00000
# total_max : 2.62986
# new step
# step : 8
# best : o1oo1
# EI_mean : 1.71758
# EI_med : 1.75566
# EI_std : 0.61628
# EI_min : 0.00000
# EI_max : 2.77181
# total_mean : 1.71758
# total_med : 1.75566
# total_std : 0.61628
# total_min : 0.00000
# total_max : 2.77181
# new step
# step : 9
# best : FC(F)F
# EI_mean : 1.84327
# EI_med : 1.75566
# EI_std : 0.67936
# EI_min : 0.00000
# EI_max : 3.27873
# total_mean : 1.84327
# total_med : 1.75566
# total_std : 0.67936
# total_min : 0.00000
# total_max : 3.27873
# Stopping : stop condition reached
# run evomol optimization
# SYMBOLS LIST : ['C', 'N', 'O', 'F']
# objective_calls
# Computing scores at initialization...
# Start pop algorithm
# EI_mean : 0.00000
# EI_med : 0.00000
# EI_std : 0.00000
# EI_min : 0.00000
# EI_max : 0.00000
# total_mean : 0.00000
# total_med : 0.00000
# total_std : 0.00000
# total_min : 0.00000
# total_max : 0.00000
# new step
# step : 0
# best : C
# EI_mean : 0.62228
# EI_med : 0.62228
# EI_std : 0.62228
# EI_min : 0.00000
# EI_max : 1.24456
# total_mean : 0.62228
# total_med : 0.62228
# total_std : 0.62228
# total_min : 0.00000
# total_max : 1.24456
# new step
# step : 1
# best : CO
# EI_mean : 0.72303
# EI_med : 0.68519
# EI_std : 0.66883
# EI_min : 0.00000
# EI_max : 1.52172
# total_mean : 0.72303
# total_med : 0.68519
# total_std : 0.66883
# total_min : 0.00000
# total_max : 1.52172
# new step
# step : 2
# best : CCO
# EI_mean : 1.04768
# EI_med : 1.24456
# EI_std : 0.59461
# EI_min : 0.00000
# EI_max : 1.75566
# total_mean : 1.04768
# total_med : 1.24456
# total_std : 0.59461
# total_min : 0.00000
# total_max : 1.75566
# new step
# step : 3
# best : CC
# EI_mean : 1.00025
# EI_med : 1.24456
# EI_std : 0.63545
# EI_min : 0.00000
# EI_max : 1.75566
# total_mean : 1.00025
# total_med : 1.24456
# total_std : 0.63545
# total_min : 0.00000
# total_max : 1.75566
# new step
# step : 4
# best : CC
# EI_mean : 1.30113
# EI_med : 1.52172
# EI_std : 0.66726
# EI_min : 0.00000
# EI_max : 2.62986
# total_mean : 1.30113
# total_med : 1.52172
# total_std : 0.66726
# total_min : 0.00000
# total_max : 2.62986
# new step
# step : 5
# best : NCOCN
# EI_mean : 1.50096
# EI_med : 1.52172
# EI_std : 0.66765
# EI_min : 0.00000
# EI_max : 2.62986
# total_mean : 1.50096
# total_med : 1.52172
# total_std : 0.66765
# total_min : 0.00000
# total_max : 2.62986
# new step
# step : 6
# best : NCOCN
# EI_mean : 1.65934
# EI_med : 1.75566
# EI_std : 0.69189
# EI_min : 0.00000
# EI_max : 3.03587
# total_mean : 1.65934
# total_med : 1.75566
# total_std : 0.69189
# total_min : 0.00000
# total_max : 3.03587
# new step
# step : 7
# best : NCCCCN
# EI_mean : 1.78968
# EI_med : 1.96191
# EI_std : 0.69400
# EI_min : 0.00000
# EI_max : 3.03587
# total_mean : 1.78968
# total_med : 1.96191
# total_std : 0.69400
# total_min : 0.00000
# total_max : 3.03587
# new step
# step : 8
# best : NCCCCN
# EI_mean : 1.84072
# EI_med : 1.96191
# EI_std : 0.66138
# EI_min : 0.00000
# EI_max : 3.03587
# total_mean : 1.84072
# total_med : 1.96191
# total_std : 0.66138
# total_min : 0.00000
# total_max : 3.03587
# new step
# step : 9
# best : NCCCCN
# EI_mean : 1.91527
# EI_med : 1.96191
# EI_std : 0.65796
# EI_min : 0.00000
# EI_max : 3.03587
# total_mean : 1.91527
# total_med : 1.96191
# total_std : 0.65796
# total_min : 0.00000
# total_max : 3.03587
# Stopping : stop condition reached
# run evomol optimization
# SYMBOLS LIST : ['C', 'N', 'O', 'F']
# objective_calls
# Computing scores at initialization...
# Start pop algorithm
# EI_mean : 0.00000
# EI_med : 0.00000
# EI_std : 0.00000
# EI_min : 0.00000
# EI_max : 0.00000
# total_mean : 0.00000
# total_med : 0.00000
# total_std : 0.00000
# total_min : 0.00000
# total_max : 0.00000
# new step
# step : 0
# best : C
# EI_mean : 0.62228
# EI_med : 0.62228
# EI_std : 0.62228
# EI_min : 0.00000
# EI_max : 1.24456
# total_mean : 0.62228
# total_med : 0.62228
# total_std : 0.62228
# total_min : 0.00000
# total_max : 1.24456
# new step
# step : 1
# best : CO
# EI_mean : 0.65374
# EI_med : 0.68519
# EI_std : 0.59250
# EI_min : 0.00000
# EI_max : 1.24456
# total_mean : 0.65374
# total_med : 0.68519
# total_std : 0.59250
# total_min : 0.00000
# total_max : 1.24456
# new step
# step : 2
# best : CO
# EI_mean : 0.76800
# EI_med : 0.68519
# EI_std : 0.69145
# EI_min : 0.00000
# EI_max : 1.75566
# total_mean : 0.76800
# total_med : 0.68519
# total_std : 0.69145
# total_min : 0.00000
# total_max : 1.75566
# new step
# step : 3
# best : OO
# EI_mean : 1.03489
# EI_med : 1.24456
# EI_std : 0.65507
# EI_min : 0.00000
# EI_max : 1.75566
# total_mean : 1.03489
# total_med : 1.24456
# total_std : 0.65507
# total_min : 0.00000
# total_max : 1.75566
# new step
# step : 4
# best : OO
# EI_mean : 1.30709
# EI_med : 1.52172
# EI_std : 0.63260
# EI_min : 0.00000
# EI_max : 2.14845
# total_mean : 1.30709
# total_med : 1.52172
# total_std : 0.63260
# total_min : 0.00000
# total_max : 2.14845
# new step
# step : 5
# best : CC(C)F
# EI_mean : 1.47611
# EI_med : 1.52172
# EI_std : 0.62603
# EI_min : 0.00000
# EI_max : 2.47979
# total_mean : 1.47611
# total_med : 1.52172
# total_std : 0.62603
# total_min : 0.00000
# total_max : 2.47979
# new step
# step : 6
# best : OCCO
# EI_mean : 1.57882
# EI_med : 1.75566
# EI_std : 0.61050
# EI_min : 0.00000
# EI_max : 2.47979
# total_mean : 1.57882
# total_med : 1.75566
# total_std : 0.61050
# total_min : 0.00000
# total_max : 2.47979
# new step
# step : 7
# best : OCCO
# EI_mean : 1.64532
# EI_med : 1.75566
# EI_std : 0.60113
# EI_min : 0.00000
# EI_max : 3.15963
# total_mean : 1.64532
# total_med : 1.75566
# total_std : 0.60113
# total_min : 0.00000
# total_max : 3.15963
# new step
# step : 8
# best : CCCCC
# EI_mean : 1.74943
# EI_med : 1.75566
# EI_std : 0.61790
# EI_min : 0.00000
# EI_max : 3.15963
# total_mean : 1.74943
# total_med : 1.75566
# total_std : 0.61790
# total_min : 0.00000
# total_max : 3.15963
# new step
# step : 9
# best : CCCCC
# EI_mean : 1.84292
# EI_med : 1.75566
# EI_std : 0.67276
# EI_min : 0.00000
# EI_max : 3.71715
# total_mean : 1.84292
# total_med : 1.75566
# total_std : 0.67276
# total_min : 0.00000
# total_max : 3.71715
# Stopping : stop condition reached
# run evomol optimization
# SYMBOLS LIST : ['C', 'N', 'O', 'F']
# objective_calls
# Computing scores at initialization...
# Start pop algorithm
# EI_mean : 0.00000
# EI_med : 0.00000
# EI_std : 0.00000
# EI_min : 0.00000
# EI_max : 0.00000
# total_mean : 0.00000
# total_med : 0.00000
# total_std : 0.00000
# total_min : 0.00000
# total_max : 0.00000
# new step
# step : 0
# best : C
# EI_mean : 0.06291
# EI_med : 0.06291
# EI_std : 0.06291
# EI_min : 0.00000
# EI_max : 0.12583
# total_mean : 0.06291
# total_med : 0.06291
# total_std : 0.06291
# total_min : 0.00000
# total_max : 0.12583
# new step
# step : 1
# best :
# EI_mean : 0.37405
# EI_med : 0.12583
# EI_std : 0.50521
# EI_min : 0.00000
# EI_max : 1.24456
# total_mean : 0.37405
# total_med : 0.12583
# total_std : 0.50521
# total_min : 0.00000
# total_max : 1.24456
# new step
# step : 2
# best : CO
# EI_mean : 0.56427
# EI_med : 0.12583
# EI_std : 0.60515
# EI_min : 0.00000
# EI_max : 1.52172
# total_mean : 0.56427
# total_med : 0.12583
# total_std : 0.60515
# total_min : 0.00000
# total_max : 1.52172
# new step
# step : 3
# best : CCO
# EI_mean : 0.96836
# EI_med : 1.24456
# EI_std : 0.63702
# EI_min : 0.00000
# EI_max : 1.75566
# total_mean : 0.96836
# total_med : 1.24456
# total_std : 0.63702
# total_min : 0.00000
# total_max : 1.75566
# new step
# step : 4
# best : CCCO
# EI_mean : 1.26546
# EI_med : 1.52172
# EI_std : 0.63797
# EI_min : 0.00000
# EI_max : 2.47979
# total_mean : 1.26546
# total_med : 1.52172
# total_std : 0.63797
# total_min : 0.00000
# total_max : 2.47979
# new step
# step : 5
# best : OCCO
# EI_mean : 1.42454
# EI_med : 1.52172
# EI_std : 0.62886
# EI_min : 0.00000
# EI_max : 2.62986
# total_mean : 1.42454
# total_med : 1.52172
# total_std : 0.62886
# total_min : 0.00000
# total_max : 2.62986
# new step
# step : 6
# best : OCCCO
# EI_mean : 1.52808
# EI_med : 1.52172
# EI_std : 0.61009
# EI_min : 0.00000
# EI_max : 2.62986
# total_mean : 1.52808
# total_med : 1.52172
# total_std : 0.61009
# total_min : 0.00000
# total_max : 2.62986
# new step
# step : 7
# best : OCCCO
# EI_mean : 1.65930
# EI_med : 1.75566
# EI_std : 0.63132
# EI_min : 0.00000
# EI_max : 2.77181
# total_mean : 1.65930
# total_med : 1.75566
# total_std : 0.63132
# total_min : 0.00000
# total_max : 2.77181
# new step
# step : 8
# best : FC(F)F
# EI_mean : 1.79751
# EI_med : 1.75566
# EI_std : 0.69867
# EI_min : 0.00000
# EI_max : 3.39365
# total_mean : 1.79751
# total_med : 1.75566
# total_std : 0.69867
# total_min : 0.00000
# total_max : 3.39365
# new step
# step : 9
# best : OC1CC=CCC1
# EI_mean : 1.91130
# EI_med : 1.75566
# EI_std : 0.73025
# EI_min : 0.00000
# EI_max : 3.50480
# total_mean : 1.91130
# total_med : 1.75566
# total_std : 0.73025
# total_min : 0.00000
# total_max : 3.50480
# Stopping : stop condition reached
# run evomol optimization
# SYMBOLS LIST : ['C', 'N', 'O', 'F']
# objective_calls
# Computing scores at initialization...
# Start pop algorithm
# EI_mean : 0.00000
# EI_med : 0.00000
# EI_std : 0.00000
# EI_min : 0.00000
# EI_max : 0.00000
# total_mean : 0.00000
# total_med : 0.00000
# total_std : 0.00000
# total_min : 0.00000
# total_max : 0.00000
# new step
# step : 0
# best : C
# EI_mean : 0.62228
# EI_med : 0.62228
# EI_std : 0.62228
# EI_min : 0.00000
# EI_max : 1.24456
# total_mean : 0.62228
# total_med : 0.62228
# total_std : 0.62228
# total_min : 0.00000
# total_max : 1.24456
# new step
# step : 1
# best : CF
# EI_mean : 0.65374
# EI_med : 0.68519
# EI_std : 0.59250
# EI_min : 0.00000
# EI_max : 1.24456
# total_mean : 0.65374
# total_med : 0.68519
# total_std : 0.59250
# total_min : 0.00000
# total_max : 1.24456
# new step
# step : 2
# best : CF
# EI_mean : 0.73875
# EI_med : 0.68519
# EI_std : 0.65293
# EI_min : 0.00000
# EI_max : 1.52172
# total_mean : 0.73875
# total_med : 0.68519
# total_std : 0.65293
# total_min : 0.00000
# total_max : 1.52172
# new step
# step : 3
# best : CCF
# EI_mean : 1.04710
# EI_med : 1.24456
# EI_std : 0.70900
# EI_min : 0.00000
# EI_max : 2.14845
# total_mean : 1.04710
# total_med : 1.24456
# total_std : 0.70900
# total_min : 0.00000
# total_max : 2.14845
# new step
# step : 4
# best : CC(F)F
# EI_mean : 1.36938
# EI_med : 1.52172
# EI_std : 0.70796
# EI_min : 0.00000
# EI_max : 2.47979
# total_mean : 1.36938
# total_med : 1.52172
# total_std : 0.70796
# total_min : 0.00000
# total_max : 2.47979
# new step
# step : 5
# best : FC#CF
# EI_mean : 1.51084
# EI_med : 1.52172
# EI_std : 0.65339
# EI_min : 0.00000
# EI_max : 2.47979
# total_mean : 1.51084
# total_med : 1.52172
# total_std : 0.65339
# total_min : 0.00000
# total_max : 2.47979
# new step
# step : 6
# best : FC#CF
# EI_mean : 1.61651
# EI_med : 1.75566
# EI_std : 0.63309
# EI_min : 0.00000
# EI_max : 2.47979
# total_mean : 1.61651
# total_med : 1.75566
# total_std : 0.63309
# total_min : 0.00000
# total_max : 2.47979
# new step
# step : 7
# best : FC#CF
# EI_mean : 1.73796
# EI_med : 1.75566
# EI_std : 0.67228
# EI_min : 0.00000
# EI_max : 3.39365
# total_mean : 1.73796
# total_med : 1.75566
# total_std : 0.67228
# total_min : 0.00000
# total_max : 3.39365
# new step
# step : 8
# best : FCCC(F)CF
# EI_mean : 1.84635
# EI_med : 1.75566
# EI_std : 0.69794
# EI_min : 0.00000
# EI_max : 3.39365
# total_mean : 1.84635
# total_med : 1.75566
# total_std : 0.69794
# total_min : 0.00000
# total_max : 3.39365
# new step
# step : 9
# best : FCCC(F)CF
# EI_mean : 1.95597
# EI_med : 1.96191
# EI_std : 0.73096
# EI_min : 0.00000
# EI_max : 3.50480
# total_mean : 1.95597
# total_med : 1.96191
# total_std : 0.73096
# total_min : 0.00000
# total_max : 3.50480
# Stopping : stop condition reached
# run evomol optimization
# SYMBOLS LIST : ['C', 'N', 'O', 'F']
# objective_calls
# Computing scores at initialization...
# Start pop algorithm
# EI_mean : 0.00000
# EI_med : 0.00000
# EI_std : 0.00000
# EI_min : 0.00000
# EI_max : 0.00000
# total_mean : 0.00000
# total_med : 0.00000
# total_std : 0.00000
# total_min : 0.00000
# total_max : 0.00000
# new step
# step : 0
# best : C
# EI_mean : 0.62228
# EI_med : 0.62228
# EI_std : 0.62228
# EI_min : 0.00000
# EI_max : 1.24456
# total_mean : 0.62228
# total_med : 0.62228
# total_std : 0.62228
# total_min : 0.00000
# total_max : 1.24456
# new step
# step : 1
# best : CO
# EI_mean : 0.65374
# EI_med : 0.68519
# EI_std : 0.59250
# EI_min : 0.00000
# EI_max : 1.24456
# total_mean : 0.65374
# total_med : 0.68519
# total_std : 0.59250
# total_min : 0.00000
# total_max : 1.24456
# new step
# step : 2
# best : CO
# EI_mean : 0.70411
# EI_med : 0.68519
# EI_std : 0.61682
# EI_min : 0.00000
# EI_max : 1.52172
# total_mean : 0.70411
# total_med : 0.68519
# total_std : 0.61682
# total_min : 0.00000
# total_max : 1.52172
# new step
# step : 3
# best : CCF
# EI_mean : 1.13232
# EI_med : 1.24456
# EI_std : 0.64002
# EI_min : 0.00000
# EI_max : 1.96191
# total_mean : 1.13232
# total_med : 1.24456
# total_std : 0.64002
# total_min : 0.00000
# total_max : 1.96191
# new step
# step : 4
# best : COC
# EI_mean : 1.38481
# EI_med : 1.52172
# EI_std : 0.65336
# EI_min : 0.00000
# EI_max : 2.77181
# total_mean : 1.38481
# total_med : 1.52172
# total_std : 0.65336
# total_min : 0.00000
# total_max : 2.77181
# new step
# step : 5
# best : CC(C)C
# EI_mean : 1.55709
# EI_med : 1.75566
# EI_std : 0.65053
# EI_min : 0.00000
# EI_max : 2.77181
# total_mean : 1.55709
# total_med : 1.75566
# total_std : 0.65053
# total_min : 0.00000
# total_max : 2.77181
# new step
# step : 6
# best : CC(C)C
# EI_mean : 1.70027
# EI_med : 1.75566
# EI_std : 0.66422
# EI_min : 0.00000
# EI_max : 2.90684
# total_mean : 1.70027
# total_med : 1.75566
# total_std : 0.66422
# total_min : 0.00000
# total_max : 2.90684
# new step
# step : 7
# best : CCC(C)C
# EI_mean : 1.84629
# EI_med : 1.85879
# EI_std : 0.69367
# EI_min : 0.00000
# EI_max : 3.03587
# total_mean : 1.84629
# total_med : 1.85879
# total_std : 0.69367
# total_min : 0.00000
# total_max : 3.03587
# new step
# step : 8
# best : CC1CCC1C
# EI_mean : 1.97188
# EI_med : 1.96191
# EI_std : 0.72792
# EI_min : 0.00000
# EI_max : 3.50480
# total_mean : 1.97188
# total_med : 1.96191
# total_std : 0.72792
# total_min : 0.00000
# total_max : 3.50480
# new step
# step : 9
# best : C1CCC1
# EI_mean : 2.12485
# EI_med : 2.14845
# EI_std : 0.80970
# EI_min : 0.00000
# EI_max : 4.38005
# total_mean : 2.12485
# total_med : 2.14845
# total_std : 0.80970
# total_min : 0.00000
# total_max : 4.38005
# Stopping : stop condition reached
# run evomol optimization
# SYMBOLS LIST : ['C', 'N', 'O', 'F']
# objective_calls
# Computing scores at initialization...
# Start pop algorithm
# EI_mean : 0.00000
# EI_med : 0.00000
# EI_std : 0.00000
# EI_min : 0.00000
# EI_max : 0.00000
# total_mean : 0.00000
# total_med : 0.00000
# total_std : 0.00000
# total_min : 0.00000
# total_max : 0.00000
# new step
# step : 0
# best : C
# EI_mean : 0.06291
# EI_med : 0.06291
# EI_std : 0.06291
# EI_min : 0.00000
# EI_max : 0.12583
# total_mean : 0.06291
# total_med : 0.06291
# total_std : 0.06291
# total_min : 0.00000
# total_max : 0.12583
# new step
# step : 1
# best :
# EI_mean : 0.09437
# EI_med : 0.12583
# EI_std : 0.05448
# EI_min : 0.00000
# EI_max : 0.12583
# total_mean : 0.09437
# total_med : 0.12583
# total_std : 0.05448
# total_min : 0.00000
# total_max : 0.12583
# new step
# step : 2
# best :
# EI_mean : 0.52962
# EI_med : 0.12583
# EI_std : 0.55521
# EI_min : 0.00000
# EI_max : 1.24456
# total_mean : 0.52962
# total_med : 0.12583
# total_std : 0.55521
# total_min : 0.00000
# total_max : 1.24456
# new step
# step : 3
# best : NF
# EI_mean : 0.94988
# EI_med : 1.24456
# EI_std : 0.62460
# EI_min : 0.00000
# EI_max : 1.75566
# total_mean : 0.94988
# total_med : 1.24456
# total_std : 0.62460
# total_min : 0.00000
# total_max : 1.75566
# new step
# step : 4
# best : FF
# EI_mean : 1.23193
# EI_med : 1.24456
# EI_std : 0.60668
# EI_min : 0.00000
# EI_max : 1.96191
# total_mean : 1.23193
# total_med : 1.24456
# total_std : 0.60668
# total_min : 0.00000
# total_max : 1.96191
# new step
# step : 5
# best : FCF
# EI_mean : 1.39159
# EI_med : 1.52172
# EI_std : 0.59733
# EI_min : 0.00000
# EI_max : 2.62986
# total_mean : 1.39159
# total_med : 1.52172
# total_std : 0.59733
# total_min : 0.00000
# total_max : 2.62986
# new step
# step : 6
# best : CC(C)(F)F
# EI_mean : 1.52740
# EI_med : 1.52172
# EI_std : 0.61178
# EI_min : 0.00000
# EI_max : 2.77181
# total_mean : 1.52740
# total_med : 1.52172
# total_std : 0.61178
# total_min : 0.00000
# total_max : 2.77181
# new step
# step : 7
# best : CCC(C)(F)F
# EI_mean : 1.64309
# EI_med : 1.75566
# EI_std : 0.62954
# EI_min : 0.00000
# EI_max : 2.77181
# total_mean : 1.64309
# total_med : 1.75566
# total_std : 0.62954
# total_min : 0.00000
# total_max : 2.77181
# new step
# step : 8
# best : CCC(C)(F)F
# EI_mean : 1.77939
# EI_med : 1.75566
# EI_std : 0.67717
# EI_min : 0.00000
# EI_max : 3.03587
# total_mean : 1.77939
# total_med : 1.75566
# total_std : 0.67717
# total_min : 0.00000
# total_max : 3.03587
# new step
# step : 9
# best : FCCCCF
# EI_mean : 1.91637
# EI_med : 1.75566
# EI_std : 0.73095
# EI_min : 0.00000
# EI_max : 3.27873
# total_mean : 1.91637
# total_med : 1.75566
# total_std : 0.73095
# total_min : 0.00000
# total_max : 3.27873
# Stopping : stop condition reached
# run evomol optimization
# SYMBOLS LIST : ['C', 'N', 'O', 'F']
# objective_calls
# Computing scores at initialization...
# Start pop algorithm
# EI_mean : 0.00000
# EI_med : 0.00000
# EI_std : 0.00000
# EI_min : 0.00000
# EI_max : 0.00000
# total_mean : 0.00000
# total_med : 0.00000
# total_std : 0.00000
# total_min : 0.00000
# total_max : 0.00000
# new step
# step : 0
# best : C
# EI_mean : 0.06291
# EI_med : 0.06291
# EI_std : 0.06291
# EI_min : 0.00000
# EI_max : 0.12583
# total_mean : 0.06291
# total_med : 0.06291
# total_std : 0.06291
# total_min : 0.00000
# total_max : 0.12583
# new step
# step : 1
# best :
# EI_mean : 0.09437
# EI_med : 0.12583
# EI_std : 0.05448
# EI_min : 0.00000
# EI_max : 0.12583
# total_mean : 0.09437
# total_med : 0.12583
# total_std : 0.05448
# total_min : 0.00000
# total_max : 0.12583
# new step
# step : 2
# best :
# EI_mean : 0.52962
# EI_med : 0.12583
# EI_std : 0.55521
# EI_min : 0.00000
# EI_max : 1.24456
# total_mean : 0.52962
# total_med : 0.12583
# total_std : 0.55521
# total_min : 0.00000
# total_max : 1.24456
# new step
# step : 3
# best : CN
# EI_mean : 0.92884
# EI_med : 1.24456
# EI_std : 0.64137
# EI_min : 0.00000
# EI_max : 1.75566
# total_mean : 0.92884
# total_med : 1.24456
# total_std : 0.64137
# total_min : 0.00000
# total_max : 1.75566
# new step
# step : 4
# best : CC
# EI_mean : 1.24366
# EI_med : 1.24456
# EI_std : 0.64572
# EI_min : 0.00000
# EI_max : 2.14845
# total_mean : 1.24366
# total_med : 1.24456
# total_std : 0.64572
# total_min : 0.00000
# total_max : 2.14845
# new step
# step : 5
# best : CC(N)N
# EI_mean : 1.42628
# EI_med : 1.52172
# EI_std : 0.62745
# EI_min : 0.00000
# EI_max : 2.47979
# total_mean : 1.42628
# total_med : 1.52172
# total_std : 0.62745
# total_min : 0.00000
# total_max : 2.47979
# new step
# step : 6
# best : CCCC
# EI_mean : 1.53556
# EI_med : 1.63869
# EI_std : 0.64068
# EI_min : 0.00000
# EI_max : 3.15963
# total_mean : 1.53556
# total_med : 1.63869
# total_std : 0.64068
# total_min : 0.00000
# total_max : 3.15963
# new step
# step : 7
# best : CCCCC
# EI_mean : 1.65759
# EI_med : 1.75566
# EI_std : 0.65872
# EI_min : 0.00000
# EI_max : 3.15963
# total_mean : 1.65759
# total_med : 1.75566
# total_std : 0.65872
# total_min : 0.00000
# total_max : 3.15963
# new step
# step : 8
# best : CCCCC
# EI_mean : 1.81483
# EI_med : 1.75566
# EI_std : 0.75320
# EI_min : 0.00000
# EI_max : 4.38005
# total_mean : 1.81483
# total_med : 1.75566
# total_std : 0.75320
# total_min : 0.00000
# total_max : 4.38005
# new step
# step : 9
# best : C1CCCC1
# EI_mean : 1.92920
# EI_med : 1.96191
# EI_std : 0.77704
# EI_min : 0.00000
# EI_max : 4.38005
# total_mean : 1.92920
# total_med : 1.96191
# total_std : 0.77704
# total_min : 0.00000
# total_max : 4.38005
# Stopping : stop condition reached
# run evomol optimization
# SYMBOLS LIST : ['C', 'N', 'O', 'F']
# objective_calls
# Computing scores at initialization...
# Start pop algorithm
# EI_mean : 0.00000
# EI_med : 0.00000
# EI_std : 0.00000
# EI_min : 0.00000
# EI_max : 0.00000
# total_mean : 0.00000
# total_med : 0.00000
# total_std : 0.00000
# total_min : 0.00000
# total_max : 0.00000
# new step
# step : 0
# best : C
# EI_mean : 0.06291
# EI_med : 0.06291
# EI_std : 0.06291
# EI_min : 0.00000
# EI_max : 0.12583
# total_mean : 0.06291
# total_med : 0.06291
# total_std : 0.06291
# total_min : 0.00000
# total_max : 0.12583
# new step
# step : 1
# best : O
# EI_mean : 0.65374
# EI_med : 0.68519
# EI_std : 0.59250
# EI_min : 0.00000
# EI_max : 1.24456
# total_mean : 0.65374
# total_med : 0.68519
# total_std : 0.59250
# total_min : 0.00000
# total_max : 1.24456
# new step
# step : 2
# best : CO
# EI_mean : 0.89897
# EI_med : 1.24456
# EI_std : 0.67187
# EI_min : 0.00000
# EI_max : 1.96191
# total_mean : 0.89897
# total_med : 1.24456
# total_std : 0.67187
# total_min : 0.00000
# total_max : 1.96191
# new step
# step : 3
# best : C1OO1
# EI_mean : 1.13059
# EI_med : 1.24456
# EI_std : 0.64307
# EI_min : 0.00000
# EI_max : 1.96191
# total_mean : 1.13059
# total_med : 1.24456
# total_std : 0.64307
# total_min : 0.00000
# total_max : 1.96191
# new step
# step : 4
# best : C1OO1
# EI_mean : 1.31362
# EI_med : 1.52172
# EI_std : 0.66487
# EI_min : 0.00000
# EI_max : 2.47979
# total_mean : 1.31362
# total_med : 1.52172
# total_std : 0.66487
# total_min : 0.00000
# total_max : 2.47979
# new step
# step : 5
# best : C1COO1
# EI_mean : 1.44937
# EI_med : 1.52172
# EI_std : 0.63739
# EI_min : 0.00000
# EI_max : 2.62986
# total_mean : 1.44937
# total_med : 1.52172
# total_std : 0.63739
# total_min : 0.00000
# total_max : 2.62986
# new step
# step : 6
# best : C1COOC1
# EI_mean : 1.55740
# EI_med : 1.75566
# EI_std : 0.61092
# EI_min : 0.00000
# EI_max : 2.62986
# total_mean : 1.55740
# total_med : 1.75566
# total_std : 0.61092
# total_min : 0.00000
# total_max : 2.62986
# new step
# step : 7
# best : C1COOC1
# EI_mean : 1.62453
# EI_med : 1.75566
# EI_std : 0.58922
# EI_min : 0.00000
# EI_max : 2.62986
# total_mean : 1.62453
# total_med : 1.75566
# total_std : 0.58922
# total_min : 0.00000
# total_max : 2.62986
# new step
# step : 8
# best : C1COOC1
# EI_mean : 1.74708
# EI_med : 1.75566
# EI_std : 0.63374
# EI_min : 0.00000
# EI_max : 3.15963
# total_mean : 1.74708
# total_med : 1.75566
# total_std : 0.63374
# total_min : 0.00000
# total_max : 3.15963
# new step
# step : 9
# best : C1CCOCOC1
# EI_mean : 1.83211
# EI_med : 1.75566
# EI_std : 0.64157
# EI_min : 0.00000
# EI_max : 3.15963
# total_mean : 1.83211
# total_med : 1.75566
# total_std : 0.64157
# total_min : 0.00000
# total_max : 3.15963
# Stopping : stop condition reached
# ['FCC(F)CF', 'C1CCOCOC1', 'C1CCCC1', 'NC(F)C(F)(F)OF', 'OC1=CCC(O)CC1', 'CC1CCCC1', 'CCCCC(C)F', 'C1#CC#C1', 'CC(F)C(F)CCF', 'NCCCCN']
# computing dft for FCC(F)CF
# Starting OPT
# Execution time OPT: 29s
# There are 11 atoms and 64 MOs
# computing dft for C1CCOCOC1
# Starting OPT
# Execution time OPT: 87s
# There are 17 atoms and 83 MOs
# computing dft for C1CCCC1
# Starting OPT
# Execution time OPT: 266s
# There are 15 atoms and 65 MOs
# computing dft for NC(F)C(F)(F)OF
# Starting OPT
# Execution time OPT: 90s
# There are 11 atoms and 78 MOs
# computing dft for OC1=CCC(O)CC1
# Starting OPT
# Execution time OPT: 132s
# There are 18 atoms and 92 MOs
# computing dft for CC1CCCC1
# Starting OPT
# Execution time OPT: 51s
# There are 18 atoms and 78 MOs
# computing dft for CCCCC(C)F
# Starting OPT
# Execution time OPT: 69s
# There are 20 atoms and 89 MOs
# computing dft for C1#CC#C1
# MM error (Evaluation error)
# computing dft for CC(F)C(F)CCF
# Starting OPT
# Execution time OPT: 88s
# There are 17 atoms and 90 MOs
# computing dft for NCCCCN
# Starting OPT
# Execution time OPT: 74s
# There are 18 atoms and 78 MOs
# step over
# model fitted
# Starting EvoMol optimizations
# run evomol optimization
# SYMBOLS LIST : ['C', 'N', 'O', 'F']
# objective_calls
# Computing scores at initialization...
# Start pop algorithm
# EI_mean : 0.00000
# EI_med : 0.00000
# EI_std : 0.00000
# EI_min : 0.00000
# EI_max : 0.00000
# total_mean : 0.00000
# total_med : 0.00000
# total_std : 0.00000
# total_min : 0.00000
# total_max : 0.00000
# new step
# step : 0
# best : OC1=CCC(O)CC1
# EI_mean : 0.00612
# EI_med : 0.00000
# EI_std : 0.01773
# EI_min : 0.00000
# EI_max : 0.07253
# total_mean : 0.00612
# total_med : 0.00000
# total_std : 0.01773
# total_min : 0.00000
# total_max : 0.07253
# new step
# step : 1
# best : NCCC1CN1
# EI_mean : 0.01841
# EI_med : 0.00000
# EI_std : 0.05888
# EI_min : 0.00000
# EI_max : 0.31019
# total_mean : 0.01841
# total_med : 0.00000
# total_std : 0.05888
# total_min : 0.00000
# total_max : 0.31019
# new step
# step : 2
# best : NC1(F)NC1(F)C(O)F
# EI_mean : 0.02880
# EI_med : 0.00074
# EI_std : 0.07054
# EI_min : 0.00000
# EI_max : 0.31019
# total_mean : 0.02880
# total_med : 0.00074
# total_std : 0.07054
# total_min : 0.00000
# total_max : 0.31019
# new step
# step : 3
# best : NC1(F)NC1(F)C(O)F
# EI_mean : 0.04737
# EI_med : 0.00242
# EI_std : 0.09128
# EI_min : 0.00000
# EI_max : 0.40615
# total_mean : 0.04737
# total_med : 0.00242
# total_std : 0.09128
# total_min : 0.00000
# total_max : 0.40615
# new step
# step : 4
# best : OCC1=CC(O)NC1
# EI_mean : 0.06331
# EI_med : 0.00306
# EI_std : 0.11168
# EI_min : 0.00000
# EI_max : 0.50945
# total_mean : 0.06331
# total_med : 0.00306
# total_std : 0.11168
# total_min : 0.00000
# total_max : 0.50945
# new step
# step : 5
# best : CC(=CCO)C(N)O
# EI_mean : 0.09435
# EI_med : 0.01996
# EI_std : 0.14488
# EI_min : 0.00000
# EI_max : 0.59765
# total_mean : 0.09435
# total_med : 0.01996
# total_std : 0.14488
# total_min : 0.00000
# total_max : 0.59765
# new step
# step : 6
# best : CCCCN(N)CCO
# EI_mean : 0.13032
# EI_med : 0.04489
# EI_std : 0.18346
# EI_min : 0.00000
# EI_max : 0.87708
# total_mean : 0.13032
# total_med : 0.04489
# total_std : 0.18346
# total_min : 0.00000
# total_max : 0.87708
# new step
# step : 7
# best : NC(O)C(F)C(N)(N)F
# EI_mean : 0.15385
# EI_med : 0.06731
# EI_std : 0.19614
# EI_min : 0.00000
# EI_max : 0.87708
# total_mean : 0.15385
# total_med : 0.06731
# total_std : 0.19614
# total_min : 0.00000
# total_max : 0.87708
# new step
# step : 8
# best : NC(O)C(F)C(N)(N)F
# EI_mean : 0.17128
# EI_med : 0.07819
# EI_std : 0.20495
# EI_min : 0.00000
# EI_max : 0.87708
# total_mean : 0.17128
# total_med : 0.07819
# total_std : 0.20495
# total_min : 0.00000
# total_max : 0.87708
# new step
# step : 9
# best : NC(O)C(F)C(N)(N)F
# EI_mean : 0.19630
# EI_med : 0.08678
# EI_std : 0.23644
# EI_min : 0.00000
# EI_max : 1.10524
# total_mean : 0.19630
# total_med : 0.08678
# total_std : 0.23644
# total_min : 0.00000
# total_max : 1.10524
# Stopping : stop condition reached
# run evomol optimization
# SYMBOLS LIST : ['C', 'N', 'O', 'F']
# objective_calls
# Computing scores at initialization...
# Start pop algorithm
# EI_mean : 0.00000
# EI_med : 0.00000
# EI_std : 0.00000
# EI_min : 0.00000
# EI_max : 0.00000
# total_mean : 0.00000
# total_med : 0.00000
# total_std : 0.00000
# total_min : 0.00000
# total_max : 0.00000
# new step
# step : 0
# best : CCCCC(C)F
# EI_mean : 0.00597
# EI_med : 0.00000
# EI_std : 0.02480
# EI_min : 0.00000
# EI_max : 0.11404
# total_mean : 0.00597
# total_med : 0.00000
# total_std : 0.02480
# total_min : 0.00000
# total_max : 0.11404
# new step
# step : 1
# best : NOC1=CCC(O)CC1
# EI_mean : 0.01376
# EI_med : 0.00000
# EI_std : 0.04189
# EI_min : 0.00000
# EI_max : 0.18877
# total_mean : 0.01376
# total_med : 0.00000
# total_std : 0.04189
# total_min : 0.00000
# total_max : 0.18877
# new step
# step : 2
# best : CC(N)=CCCO
# EI_mean : 0.01784
# EI_med : 0.00000
# EI_std : 0.04077
# EI_min : 0.00000
# EI_max : 0.18877
# total_mean : 0.01784
# total_med : 0.00000
# total_std : 0.04077
# total_min : 0.00000
# total_max : 0.18877
# new step
# step : 3
# best : CC(N)=CCCO
# EI_mean : 0.05301
# EI_med : 0.00116
# EI_std : 0.12278
# EI_min : 0.00000
# EI_max : 0.64662
# total_mean : 0.05301
# total_med : 0.00116
# total_std : 0.12278
# total_min : 0.00000
# total_max : 0.64662
# new step
# step : 4
# best : NC1C=C(O)CCC1O
# EI_mean : 0.07260
# EI_med : 0.00312
# EI_std : 0.13483
# EI_min : 0.00000
# EI_max : 0.64662
# total_mean : 0.07260
# total_med : 0.00312
# total_std : 0.13483
# total_min : 0.00000
# total_max : 0.64662
# new step
# step : 5
# best : NC1C=C(O)CCC1O
# EI_mean : 0.10002
# EI_med : 0.01492
# EI_std : 0.16683
# EI_min : 0.00000
# EI_max : 0.82309
# total_mean : 0.10002
# total_med : 0.01492
# total_std : 0.16683
# total_min : 0.00000
# total_max : 0.82309
# new step
# step : 6
# best : NCCCCC(N)N
# EI_mean : 0.12395
# EI_med : 0.04097
# EI_std : 0.17584
# EI_min : 0.00000
# EI_max : 0.82309
# total_mean : 0.12395
# total_med : 0.04097
# total_std : 0.17584
# total_min : 0.00000
# total_max : 0.82309
# new step
# step : 7
# best : NCCCCC(N)N
# EI_mean : 0.15805
# EI_med : 0.05960
# EI_std : 0.20976
# EI_min : 0.00000
# EI_max : 0.85708
# total_mean : 0.15805
# total_med : 0.05960
# total_std : 0.20976
# total_min : 0.00000
# total_max : 0.85708
# new step
# step : 8
# best : NC1CCC(O)CC1O
# EI_mean : 0.18703
# EI_med : 0.08183
# EI_std : 0.23671
# EI_min : 0.00000
# EI_max : 0.94246
# total_mean : 0.18703
# total_med : 0.08183
# total_std : 0.23671
# total_min : 0.00000
# total_max : 0.94246
# new step
# step : 9
# best : CC(F)C(N)(CN)CN
# EI_mean : 0.21029
# EI_med : 0.11167
# EI_std : 0.24836
# EI_min : 0.00000
# EI_max : 0.94246
# total_mean : 0.21029
# total_med : 0.11167
# total_std : 0.24836
# total_min : 0.00000
# total_max : 0.94246
# Stopping : stop condition reached
# run evomol optimization
# SYMBOLS LIST : ['C', 'N', 'O', 'F']
# objective_calls
# Computing scores at initialization...
# Start pop algorithm
# EI_mean : 0.00000
# EI_med : 0.00000
# EI_std : 0.00000
# EI_min : 0.00000
# EI_max : 0.00000
# total_mean : 0.00000
# total_med : 0.00000
# total_std : 0.00000
# total_min : 0.00000
# total_max : 0.00000
# new step
# step : 0
# best : FCC(F)CF
# EI_mean : 0.04323
# EI_med : 0.00000
# EI_std : 0.10135
# EI_min : 0.00000
# EI_max : 0.37418
# total_mean : 0.04323
# total_med : 0.00000
# total_std : 0.10135
# total_min : 0.00000
# total_max : 0.37418
# new step
# step : 1
# best : CC(O)CC(N)=CO
# EI_mean : 0.05125
# EI_med : 0.00014
# EI_std : 0.09884
# EI_min : 0.00000
# EI_max : 0.37418
# total_mean : 0.05125
# total_med : 0.00014
# total_std : 0.09884
# total_min : 0.00000
# total_max : 0.37418
# new step
# step : 2
# best : CC(O)CC(N)=CO
# EI_mean : 0.07327
# EI_med : 0.00221
# EI_std : 0.13457
# EI_min : 0.00000
# EI_max : 0.65196
# total_mean : 0.07327
# total_med : 0.00221
# total_std : 0.13457
# total_min : 0.00000
# total_max : 0.65196
# new step
# step : 3
# best : NCC1OCC#CCO1
# EI_mean : 0.09174
# EI_med : 0.01682
# EI_std : 0.14022
# EI_min : 0.00000
# EI_max : 0.65196
# total_mean : 0.09174
# total_med : 0.01682
# total_std : 0.14022
# total_min : 0.00000
# total_max : 0.65196
# new step
# step : 4
# best : NCC1OCC#CCO1
# EI_mean : 0.13009
# EI_med : 0.04357
# EI_std : 0.17641
# EI_min : 0.00000
# EI_max : 0.76481
# total_mean : 0.13009
# total_med : 0.04357
# total_std : 0.17641
# total_min : 0.00000
# total_max : 0.76481
# new step
# step : 5
# best : NCC1OCCCCO1
# EI_mean : 0.14807
# EI_med : 0.08420
# EI_std : 0.17705
# EI_min : 0.00000
# EI_max : 0.76481
# total_mean : 0.14807
# total_med : 0.08420
# total_std : 0.17705
# total_min : 0.00000
# total_max : 0.76481
# new step
# step : 6
# best : NCC1OCCCCO1
# EI_mean : 0.17060
# EI_med : 0.10194
# EI_std : 0.18313
# EI_min : 0.00000
# EI_max : 0.76481
# total_mean : 0.17060
# total_med : 0.10194
# total_std : 0.18313
# total_min : 0.00000
# total_max : 0.76481
# new step
# step : 7
# best : NCC1OCCCCO1
# EI_mean : 0.20098
# EI_med : 0.13861
# EI_std : 0.20635
# EI_min : 0.00000
# EI_max : 0.77295
# total_mean : 0.20098
# total_med : 0.13861
# total_std : 0.20635
# total_min : 0.00000
# total_max : 0.77295
# new step
# step : 8
# best : C1CNCCNC1
# EI_mean : 0.21795
# EI_med : 0.15812
# EI_std : 0.21337
# EI_min : 0.00000
# EI_max : 0.77466
# total_mean : 0.21795
# total_med : 0.15812
# total_std : 0.21337
# total_min : 0.00000
# total_max : 0.77466
# new step
# step : 9
# best : CCNC(N)(N)C(C)O
# EI_mean : 0.23407
# EI_med : 0.17738
# EI_std : 0.22787
# EI_min : 0.00000
# EI_max : 0.83556
# total_mean : 0.23407
# total_med : 0.17738
# total_std : 0.22787
# total_min : 0.00000
# total_max : 0.83556
# Stopping : stop condition reached
# run evomol optimization
# SYMBOLS LIST : ['C', 'N', 'O', 'F']
# objective_calls
# Computing scores at initialization...
# Start pop algorithm
# EI_mean : 0.00000
# EI_med : 0.00000
# EI_std : 0.00000
# EI_min : 0.00000
# EI_max : 0.00000
# total_mean : 0.00000
# total_med : 0.00000
# total_std : 0.00000
# total_min : 0.00000
# total_max : 0.00000
# new step
# step : 0
# best : C1CCOCOC1
# EI_mean : 0.03483
# EI_med : 0.00000
# EI_std : 0.14053
# EI_min : 0.00000
# EI_max : 0.64662
# total_mean : 0.03483
# total_med : 0.00000
# total_std : 0.14053
# total_min : 0.00000
# total_max : 0.64662
# new step
# step : 1
# best : NC1C(O)=CCCC1O
# EI_mean : 0.05004
# EI_med : 0.00000
# EI_std : 0.15561
# EI_min : 0.00000
# EI_max : 0.64662
# total_mean : 0.05004
# total_med : 0.00000
# total_std : 0.15561
# total_min : 0.00000
# total_max : 0.64662
# new step
# step : 2
# best : NC1C(O)=CCCC1O
# EI_mean : 0.06684
# EI_med : 0.00474
# EI_std : 0.16750
# EI_min : 0.00000
# EI_max : 0.64662
# total_mean : 0.06684
# total_med : 0.00474
# total_std : 0.16750
# total_min : 0.00000
# total_max : 0.64662
# new step
# step : 3
# best : NC1C(O)=CCCC1O
# EI_mean : 0.08245
# EI_med : 0.01195
# EI_std : 0.16753
# EI_min : 0.00000
# EI_max : 0.64662
# total_mean : 0.08245
# total_med : 0.01195
# total_std : 0.16753
# total_min : 0.00000
# total_max : 0.64662
# new step
# step : 4
# best : NC1C(O)=CCCC1O
# EI_mean : 0.11683
# EI_med : 0.02688
# EI_std : 0.20335
# EI_min : 0.00000
# EI_max : 1.02087
# total_mean : 0.11683
# total_med : 0.02688
# total_std : 0.20335
# total_min : 0.00000
# total_max : 1.02087
# new step
# step : 5
# best : NCC(O)=C1CC1CO
# EI_mean : 0.14731
# EI_med : 0.03370
# EI_std : 0.22351
# EI_min : 0.00000
# EI_max : 1.02087
# total_mean : 0.14731
# total_med : 0.03370
# total_std : 0.22351
# total_min : 0.00000
# total_max : 1.02087
# new step
# step : 6
# best : NCC(O)=C1CC1CO
# EI_mean : 0.19465
# EI_med : 0.06371
# EI_std : 0.26409
# EI_min : 0.00000
# EI_max : 1.02087
# total_mean : 0.19465
# total_med : 0.06371
# total_std : 0.26409
# total_min : 0.00000
# total_max : 1.02087
# new step
# step : 7
# best : NCC(O)=C1CC1CO
# EI_mean : 0.23638
# EI_med : 0.09668
# EI_std : 0.28815
# EI_min : 0.00000
# EI_max : 1.02087
# total_mean : 0.23638
# total_med : 0.09668
# total_std : 0.28815
# total_min : 0.00000
# total_max : 1.02087
# new step
# step : 8
# best : NCC(O)=C1CC1CO
# EI_mean : 0.27392
# EI_med : 0.11388
# EI_std : 0.32340
# EI_min : 0.00000
# EI_max : 1.52452
# total_mean : 0.27392
# total_med : 0.11388
# total_std : 0.32340
# total_min : 0.00000
# total_max : 1.52452
# new step
# step : 9
# best : CC(N)=C(O)C(O)CN
# EI_mean : 0.29981
# EI_med : 0.17620
# EI_std : 0.32875
# EI_min : 0.00000
# EI_max : 1.52452
# total_mean : 0.29981
# total_med : 0.17620
# total_std : 0.32875
# total_min : 0.00000
# total_max : 1.52452
# Stopping : stop condition reached
# run evomol optimization
# SYMBOLS LIST : ['C', 'N', 'O', 'F']
# objective_calls
# Computing scores at initialization...
# Start pop algorithm
# EI_mean : 0.00000
# EI_med : 0.00000
# EI_std : 0.00000
# EI_min : 0.00000
# EI_max : 0.00000
# total_mean : 0.00000
# total_med : 0.00000
# total_std : 0.00000
# total_min : 0.00000
# total_max : 0.00000
# new step
# step : 0
# best : C1CCCC1
# EI_mean : 0.02708
# EI_med : 0.00001
# EI_std : 0.07476
# EI_min : 0.00000
# EI_max : 0.30760
# total_mean : 0.02708
# total_med : 0.00001
# total_std : 0.07476
# total_min : 0.00000
# total_max : 0.30760
# new step
# step : 1
# best : NCCCCCO
# EI_mean : 0.05106
# EI_med : 0.00331
# EI_std : 0.11432
# EI_min : 0.00000
# EI_max : 0.51165
# total_mean : 0.05106
# total_med : 0.00331
# total_std : 0.11432
# total_min : 0.00000
# total_max : 0.51165
# new step
# step : 2
# best : OC=C(O)CCO
# EI_mean : 0.08999
# EI_med : 0.00553
# EI_std : 0.19141
# EI_min : 0.00000
# EI_max : 1.00294
# total_mean : 0.08999
# total_med : 0.00553
# total_std : 0.19141
# total_min : 0.00000
# total_max : 1.00294
# new step
# step : 3
# best : OC=C(CO)CCCO
# EI_mean : 0.10604
# EI_med : 0.02541
# EI_std : 0.18208
# EI_min : 0.00000
# EI_max : 1.00294
# total_mean : 0.10604
# total_med : 0.02541
# total_std : 0.18208
# total_min : 0.00000
# total_max : 1.00294
# new step
# step : 4
# best : OC=C(CO)CCCO
# EI_mean : 0.13922
# EI_med : 0.04036
# EI_std : 0.20616
# EI_min : 0.00000
# EI_max : 1.00294
# total_mean : 0.13922
# total_med : 0.04036
# total_std : 0.20616
# total_min : 0.00000
# total_max : 1.00294
# new step
# step : 5
# best : OC=C(CO)CCCO
# EI_mean : 0.15944
# EI_med : 0.05930
# EI_std : 0.20501
# EI_min : 0.00000
# EI_max : 1.00294
# total_mean : 0.15944
# total_med : 0.05930
# total_std : 0.20501
# total_min : 0.00000
# total_max : 1.00294
# new step
# step : 6
# best : OC=C(CO)CCCO
# EI_mean : 0.17093
# EI_med : 0.08995
# EI_std : 0.20270
# EI_min : 0.00000
# EI_max : 1.00294
# total_mean : 0.17093
# total_med : 0.08995
# total_std : 0.20270
# total_min : 0.00000
# total_max : 1.00294
# new step
# step : 7
# best : OC=C(CO)CCCO
# EI_mean : 0.18535
# EI_med : 0.10054
# EI_std : 0.20782
# EI_min : 0.00000
# EI_max : 1.00294
# total_mean : 0.18535
# total_med : 0.10054
# total_std : 0.20782
# total_min : 0.00000
# total_max : 1.00294
# new step
# step : 8
# best : OC=C(CO)CCCO
# EI_mean : 0.19350
# EI_med : 0.13331
# EI_std : 0.20748
# EI_min : 0.00000
# EI_max : 1.00294
# total_mean : 0.19350
# total_med : 0.13331
# total_std : 0.20748
# total_min : 0.00000
# total_max : 1.00294
# new step
# step : 9
# best : OC=C(CO)CCCO
# EI_mean : 0.22018
# EI_med : 0.16158
# EI_std : 0.23934
# EI_min : 0.00000
# EI_max : 1.37630
# total_mean : 0.22018
# total_med : 0.16158
# total_std : 0.23934
# total_min : 0.00000
# total_max : 1.37630
# Stopping : stop condition reached
# run evomol optimization
# SYMBOLS LIST : ['C', 'N', 'O', 'F']
# objective_calls
# Computing scores at initialization...
# Start pop algorithm
# EI_mean : 0.00000
# EI_med : 0.00000
# EI_std : 0.00000
# EI_min : 0.00000
# EI_max : 0.00000
# total_mean : 0.00000
# total_med : 0.00000
# total_std : 0.00000
# total_min : 0.00000
# total_max : 0.00000
# new step
# step : 0
# best : OC1=CCC(O)CC1
# EI_mean : 0.08872
# EI_med : 0.00000
# EI_std : 0.24920
# EI_min : 0.00000
# EI_max : 1.02379
# total_mean : 0.08872
# total_med : 0.00000
# total_std : 0.24920
# total_min : 0.00000
# total_max : 1.02379
# new step
# step : 1
# best : NCCC(O)CN
# EI_mean : 0.08340
# EI_med : 0.00000
# EI_std : 0.21535
# EI_min : 0.00000
# EI_max : 1.02379
# total_mean : 0.08340
# total_med : 0.00000
# total_std : 0.21535
# total_min : 0.00000
# total_max : 1.02379
# new step
# step : 2
# best : NCCC(O)CN
# EI_mean : 0.09355
# EI_med : 0.00713
# EI_std : 0.19635
# EI_min : 0.00000
# EI_max : 1.02379
# total_mean : 0.09355
# total_med : 0.00713
# total_std : 0.19635
# total_min : 0.00000
# total_max : 1.02379
# new step
# step : 3
# best : NCCC(O)CN
# EI_mean : 0.12115
# EI_med : 0.01847
# EI_std : 0.22816
# EI_min : 0.00000
# EI_max : 1.02379
# total_mean : 0.12115
# total_med : 0.01847
# total_std : 0.22816
# total_min : 0.00000
# total_max : 1.02379
# new step
# step : 4
# best : NCCC(O)CN
# EI_mean : 0.13920
# EI_med : 0.04262
# EI_std : 0.23118
# EI_min : 0.00000
# EI_max : 1.02379
# total_mean : 0.13920
# total_med : 0.04262
# total_std : 0.23118
# total_min : 0.00000
# total_max : 1.02379
# new step
# step : 5
# best : NCCC(O)CN
# EI_mean : 0.19324
# EI_med : 0.07355
# EI_std : 0.28368
# EI_min : 0.00000
# EI_max : 1.41059
# total_mean : 0.19324
# total_med : 0.07355
# total_std : 0.28368
# total_min : 0.00000
# total_max : 1.41059
# new step
# step : 6
# best : NCCCC(O)CN
# EI_mean : 0.21532
# EI_med : 0.09356
# EI_std : 0.28418
# EI_min : 0.00000
# EI_max : 1.41059
# total_mean : 0.21532
# total_med : 0.09356
# total_std : 0.28418
# total_min : 0.00000
# total_max : 1.41059
# new step
# step : 7
# best : NCCCC(O)CN
# EI_mean : 0.22248
# EI_med : 0.12239
# EI_std : 0.27505
# EI_min : 0.00000
# EI_max : 1.41059
# total_mean : 0.22248
# total_med : 0.12239
# total_std : 0.27505
# total_min : 0.00000
# total_max : 1.41059
# new step
# step : 8
# best : NCCCC(O)CN
# EI_mean : 0.22627
# EI_med : 0.14053
# EI_std : 0.26612
# EI_min : 0.00000
# EI_max : 1.41059
# total_mean : 0.22627
# total_med : 0.14053
# total_std : 0.26612
# total_min : 0.00000
# total_max : 1.41059
# new step
# step : 9
# best : NCCCC(O)CN
# EI_mean : 0.25431
# EI_med : 0.14999
# EI_std : 0.31334
# EI_min : 0.00000
# EI_max : 1.71527
# total_mean : 0.25431
# total_med : 0.14999
# total_std : 0.31334
# total_min : 0.00000
# total_max : 1.71527
# Stopping : stop condition reached
# run evomol optimization
# SYMBOLS LIST : ['C', 'N', 'O', 'F']
# objective_calls
# Computing scores at initialization...
# Start pop algorithm
# EI_mean : 0.00000
# EI_med : 0.00000
# EI_std : 0.00000
# EI_min : 0.00000
# EI_max : 0.00000
# total_mean : 0.00000
# total_med : 0.00000
# total_std : 0.00000
# total_min : 0.00000
# total_max : 0.00000
# new step
# step : 0
# best : OC1=CCC(O)CC1
# EI_mean : 0.02290
# EI_med : 0.00000
# EI_std : 0.07189
# EI_min : 0.00000
# EI_max : 0.32789
# total_mean : 0.02290
# total_med : 0.00000
# total_std : 0.07189
# total_min : 0.00000
# total_max : 0.32789
# new step
# step : 1
# best : OC1CCC(F)OCO1
# EI_mean : 0.03477
# EI_med : 0.00000
# EI_std : 0.08197
# EI_min : 0.00000
# EI_max : 0.32925
# total_mean : 0.03477
# total_med : 0.00000
# total_std : 0.08197
# total_min : 0.00000
# total_max : 0.32925
# new step
# step : 2
# best : FC1CCC2OC(O1)O2
# EI_mean : 0.04690
# EI_med : 0.00855
# EI_std : 0.08314
# EI_min : 0.00000
# EI_max : 0.32925
# total_mean : 0.04690
# total_med : 0.00855
# total_std : 0.08314
# total_min : 0.00000
# total_max : 0.32925
# new step
# step : 3
# best : FC1CCC2OC(O1)O2
# EI_mean : 0.07773
# EI_med : 0.01978
# EI_std : 0.10989
# EI_min : 0.00000
# EI_max : 0.34788
# total_mean : 0.07773
# total_med : 0.01978
# total_std : 0.10989
# total_min : 0.00000
# total_max : 0.34788
# new step
# step : 4
# best : NC1CCC(F)OCO1
# EI_mean : 0.10239
# EI_med : 0.03652
# EI_std : 0.12702
# EI_min : 0.00000
# EI_max : 0.43239
# total_mean : 0.10239
# total_med : 0.03652
# total_std : 0.12702
# total_min : 0.00000
# total_max : 0.43239
# new step
# step : 5
# best : NC1CNC(F)OCO1
# EI_mean : 0.11399
# EI_med : 0.06909
# EI_std : 0.12556
# EI_min : 0.00000
# EI_max : 0.43239
# total_mean : 0.11399
# total_med : 0.06909
# total_std : 0.12556
# total_min : 0.00000
# total_max : 0.43239
# new step
# step : 6
# best : NC1CNC(F)OCO1
# EI_mean : 0.13237
# EI_med : 0.09533
# EI_std : 0.13627
# EI_min : 0.00000
# EI_max : 0.48252
# total_mean : 0.13237
# total_med : 0.09533
# total_std : 0.13627
# total_min : 0.00000
# total_max : 0.48252
# new step
# step : 7
# best : NC1CCC2(O)OC1O2
# EI_mean : 0.15496
# EI_med : 0.11675
# EI_std : 0.16130
# EI_min : 0.00000
# EI_max : 0.74617
# total_mean : 0.15496
# total_med : 0.11675
# total_std : 0.16130
# total_min : 0.00000
# total_max : 0.74617
# new step
# step : 8
# best : CCOCCOC(N)F
# EI_mean : 0.17025
# EI_med : 0.12412
# EI_std : 0.16620
# EI_min : 0.00000
# EI_max : 0.74617
# total_mean : 0.17025
# total_med : 0.12412
# total_std : 0.16620
# total_min : 0.00000
# total_max : 0.74617
# new step
# step : 9
# best : CCOCCOC(N)F
# EI_mean : 0.18106
# EI_med : 0.15009
# EI_std : 0.16761
# EI_min : 0.00000
# EI_max : 0.74617
# total_mean : 0.18106
# total_med : 0.15009
# total_std : 0.16761
# total_min : 0.00000
# total_max : 0.74617
# Stopping : stop condition reached
# run evomol optimization
# SYMBOLS LIST : ['C', 'N', 'O', 'F']
# objective_calls
# Computing scores at initialization...
# Start pop algorithm
# EI_mean : 0.00000
# EI_med : 0.00000
# EI_std : 0.00000
# EI_min : 0.00000
# EI_max : 0.00000
# total_mean : 0.00000
# total_med : 0.00000
# total_std : 0.00000
# total_min : 0.00000
# total_max : 0.00000
# new step
# step : 0
# best : C1CCOCOC1
# EI_mean : 0.03829
# EI_med : 0.00000
# EI_std : 0.09430
# EI_min : 0.00000
# EI_max : 0.35797
# total_mean : 0.03829
# total_med : 0.00000
# total_std : 0.09430
# total_min : 0.00000
# total_max : 0.35797
# new step
# step : 1
# best : C1=CCOCOCC1
# EI_mean : 0.08736
# EI_med : 0.00003
# EI_std : 0.19267
# EI_min : 0.00000
# EI_max : 0.89190
# total_mean : 0.08736
# total_med : 0.00003
# total_std : 0.19267
# total_min : 0.00000
# total_max : 0.89190
# new step
# step : 2
# best : OC1CC=CC2OC2C1
# EI_mean : 0.09191
# EI_med : 0.00521
# EI_std : 0.17516
# EI_min : 0.00000
# EI_max : 0.89190
# total_mean : 0.09191
# total_med : 0.00521
# total_std : 0.17516
# total_min : 0.00000
# total_max : 0.89190
# new step
# step : 3
# best : OC1CC=CC2OC2C1
# EI_mean : 0.13477
# EI_med : 0.01564
# EI_std : 0.20881
# EI_min : 0.00000
# EI_max : 0.89190
# total_mean : 0.13477
# total_med : 0.01564
# total_std : 0.20881
# total_min : 0.00000
# total_max : 0.89190
# new step
# step : 4
# best : OC1CC=CC2OC2C1
# EI_mean : 0.14790
# EI_med : 0.05595
# EI_std : 0.19986
# EI_min : 0.00000
# EI_max : 0.89190
# total_mean : 0.14790
# total_med : 0.05595
# total_std : 0.19986
# total_min : 0.00000
# total_max : 0.89190
# new step
# step : 5
# best : OC1CC=CC2OC2C1
# EI_mean : 0.18197
# EI_med : 0.11023
# EI_std : 0.23615
# EI_min : 0.00000
# EI_max : 1.10803
# total_mean : 0.18197
# total_med : 0.11023
# total_std : 0.23615
# total_min : 0.00000
# total_max : 1.10803
# new step
# step : 6
# best : NCCCCCC(N)N
# EI_mean : 0.20841
# EI_med : 0.13866
# EI_std : 0.25330
# EI_min : 0.00000
# EI_max : 1.10803
# total_mean : 0.20841
# total_med : 0.13866
# total_std : 0.25330
# total_min : 0.00000
# total_max : 1.10803
# new step
# step : 7
# best : NCCCCCC(N)N
# EI_mean : 0.23433
# EI_med : 0.15008
# EI_std : 0.28669
# EI_min : 0.00000
# EI_max : 1.45425
# total_mean : 0.23433
# total_med : 0.15008
# total_std : 0.28669
# total_min : 0.00000
# total_max : 1.45425
# new step
# step : 8
# best : NCCCCC(N)CN
# EI_mean : 0.26594
# EI_med : 0.17705
# EI_std : 0.30175
# EI_min : 0.00000
# EI_max : 1.45425
# total_mean : 0.26594
# total_med : 0.17705
# total_std : 0.30175
# total_min : 0.00000
# total_max : 1.45425
# new step
# step : 9
# best : NCCCCC(N)CN
# EI_mean : 0.30003
# EI_med : 0.20676
# EI_std : 0.33638
# EI_min : 0.00000
# EI_max : 1.81676
# total_mean : 0.30003
# total_med : 0.20676
# total_std : 0.33638
# total_min : 0.00000
# total_max : 1.81676
# Stopping : stop condition reached
# run evomol optimization
# SYMBOLS LIST : ['C', 'N', 'O', 'F']
# objective_calls
# Computing scores at initialization...
# Start pop algorithm
# EI_mean : 0.00000
# EI_med : 0.00000
# EI_std : 0.00000
# EI_min : 0.00000
# EI_max : 0.00000
# total_mean : 0.00000
# total_med : 0.00000
# total_std : 0.00000
# total_min : 0.00000
# total_max : 0.00000
# new step
# step : 0
# best : CC1CCCC1
# EI_mean : 0.02743
# EI_med : 0.00000
# EI_std : 0.08104
# EI_min : 0.00000
# EI_max : 0.35845
# total_mean : 0.02743
# total_med : 0.00000
# total_std : 0.08104
# total_min : 0.00000
# total_max : 0.35845
# new step
# step : 1
# best : NCCCCCN
# EI_mean : 0.03703
# ...
# Start pop algorithm
# EI_mean : 0.00000
# EI_med : 0.00000
# EI_std : 0.00000
# EI_min : 0.00000
# EI_max : 0.00000
# total_mean : 0.00000
# total_med : 0.00000
# total_std : 0.00000
# total_min : 0.00000
# total_max : 0.00000
# new step
# step : 0
# best : CCC(N)(N)C(O)=CO
# EI_mean : 0.00069
# EI_med : 0.00000
# EI_std : 0.00175
# EI_min : 0.00000
# EI_max : 0.00708
# total_mean : 0.00069
# total_med : 0.00000
# total_std : 0.00175
# total_min : 0.00000
# total_max : 0.00708
# new step
# step : 1
# best : NC1(O)NCC(O)=C1O
# EI_mean : 0.00129
# EI_med : 0.00000
# EI_std : 0.00321
# EI_min : 0.00000
# EI_max : 0.01607
# total_mean : 0.00129
# total_med : 0.00000
# total_std : 0.00321
# total_min : 0.00000
# total_max : 0.01607
# new step
# step : 2
# best : CC(=CO)N=NCN
# EI_mean : 0.00231
# EI_med : 0.00000
# EI_std : 0.00614
# EI_min : 0.00000
# EI_max : 0.03291
# total_mean : 0.00231
# total_med : 0.00000
# total_std : 0.00614
# total_min : 0.00000
# total_max : 0.03291
# new step
# step : 3
# best : ONOC1=C(O)CNC1
# EI_mean : 0.00248
# EI_med : 0.00003
# EI_std : 0.00595
# EI_min : 0.00000
# EI_max : 0.03291
# total_mean : 0.00248
# total_med : 0.00003
# total_std : 0.00595
# total_min : 0.00000
# total_max : 0.03291
# new step
# step : 4
# best : ONOC1=C(O)CNC1
# EI_mean : 0.00301
# EI_med : 0.00010
# EI_std : 0.00591
# EI_min : 0.00000
# EI_max : 0.03291
# total_mean : 0.00301
# total_med : 0.00010
# total_std : 0.00591
# total_min : 0.00000
# total_max : 0.03291
# new step
# step : 5
# best : ONOC1=C(O)CNC1
# EI_mean : 0.00394
# EI_med : 0.00050
# EI_std : 0.00802
# EI_min : 0.00000
# EI_max : 0.04504
# total_mean : 0.00394
# total_med : 0.00050
# total_std : 0.00802
# total_min : 0.00000
# total_max : 0.04504
# new step
# step : 6
# best : NC1NC2(O)OC2=C1O
# EI_mean : 0.00383
# EI_med : 0.00050
# EI_std : 0.00760
# EI_min : 0.00000
# EI_max : 0.04504
# total_mean : 0.00383
# total_med : 0.00050
# total_std : 0.00760
# total_min : 0.00000
# total_max : 0.04504
# new step
# step : 7
# best : NC1NC2(O)OC2=C1O
# EI_mean : 0.00471
# EI_med : 0.00059
# EI_std : 0.01215
# EI_min : 0.00000
# EI_max : 0.09664
# total_mean : 0.00471
# total_med : 0.00059
# total_std : 0.01215
# total_min : 0.00000
# total_max : 0.09664
# new step
# step : 8
# best : NCC=C(O)C(N)N
# EI_mean : 0.00522
# EI_med : 0.00062
# EI_std : 0.01310
# EI_min : 0.00000
# EI_max : 0.09664
# total_mean : 0.00522
# total_med : 0.00062
# total_std : 0.01310
# total_min : 0.00000
# total_max : 0.09664
# new step
# step : 9
# best : NCC=C(O)C(N)N
# EI_mean : 0.00561
# EI_med : 0.00080
# EI_std : 0.01321
# EI_min : 0.00000
# EI_max : 0.09664
# total_mean : 0.00561
# total_med : 0.00080
# total_std : 0.01321
# total_min : 0.00000
# total_max : 0.09664
# Stopping : stop condition reached
# run evomol optimization
# SYMBOLS LIST : ['C', 'N', 'O', 'F']
# objective_calls
# Computing scores at initialization...
# Start pop algorithm
# EI_mean : 0.00000
# EI_med : 0.00000
# EI_std : 0.00000
# EI_min : 0.00000
# EI_max : 0.00000
# total_mean : 0.00000
# total_med : 0.00000
# total_std : 0.00000
# total_min : 0.00000
# total_max : 0.00000
# new step
# step : 0
# best : C1CCCC1
# EI_mean : 0.00052
# EI_med : 0.00000
# EI_std : 0.00210
# EI_min : 0.00000
# EI_max : 0.00967
# total_mean : 0.00052
# total_med : 0.00000
# total_std : 0.00210
# total_min : 0.00000
# total_max : 0.00967
# new step
# step : 1
# best : NCC(=CO)CC(N)O
# EI_mean : 0.00069
# EI_med : 0.00000
# EI_std : 0.00225
# EI_min : 0.00000
# EI_max : 0.00967
# total_mean : 0.00069
# total_med : 0.00000
# total_std : 0.00225
# total_min : 0.00000
# total_max : 0.00967
# new step
# step : 2
# best : NCC(=CO)CC(N)O
# EI_mean : 0.00074
# EI_med : 0.00000
# EI_std : 0.00212
# EI_min : 0.00000
# EI_max : 0.00967
# total_mean : 0.00074
# total_med : 0.00000
# total_std : 0.00212
# total_min : 0.00000
# total_max : 0.00967
# new step
# step : 3
# best : NCC(=CO)CC(N)O
# EI_mean : 0.00067
# EI_med : 0.00006
# EI_std : 0.00191
# EI_min : 0.00000
# EI_max : 0.00967
# total_mean : 0.00067
# total_med : 0.00006
# total_std : 0.00191
# total_min : 0.00000
# total_max : 0.00967
# new step
# step : 4
# best : NCC(=CO)CC(N)O
# EI_mean : 0.00127
# EI_med : 0.00009
# EI_std : 0.00435
# EI_min : 0.00000
# EI_max : 0.03107
# total_mean : 0.00127
# total_med : 0.00009
# total_std : 0.00435
# total_min : 0.00000
# total_max : 0.03107
# new step
# step : 5
# best : NC1=NCC2(O)OC12O
# EI_mean : 0.00137
# EI_med : 0.00012
# EI_std : 0.00429
# EI_min : 0.00000
# EI_max : 0.03107
# total_mean : 0.00137
# total_med : 0.00012
# total_std : 0.00429
# total_min : 0.00000
# total_max : 0.03107
# new step
# step : 6
# best : NC1=NCC2(O)OC12O
# EI_mean : 0.00305
# EI_med : 0.00014
# EI_std : 0.00903
# EI_min : 0.00000
# EI_max : 0.06159
# total_mean : 0.00305
# total_med : 0.00014
# total_std : 0.00903
# total_min : 0.00000
# total_max : 0.06159
# new step
# step : 7
# best : NC1NCC2(O)OC12O
# EI_mean : 0.00315
# EI_med : 0.00021
# EI_std : 0.00869
# EI_min : 0.00000
# EI_max : 0.06159
# total_mean : 0.00315
# total_med : 0.00021
# total_std : 0.00869
# total_min : 0.00000
# total_max : 0.06159
# new step
# step : 8
# best : NC1NCC2(O)OC12O
# EI_mean : 0.00385
# EI_med : 0.00025
# EI_std : 0.01115
# EI_min : 0.00000
# EI_max : 0.07787
# total_mean : 0.00385
# total_med : 0.00025
# total_std : 0.01115
# total_min : 0.00000
# total_max : 0.07787
# new step
# step : 9
# best : NCC=C(O)CC(N)F
# EI_mean : 0.00426
# EI_med : 0.00028
# EI_std : 0.01095
# EI_min : 0.00000
# EI_max : 0.07787
# total_mean : 0.00426
# total_med : 0.00028
# total_std : 0.01095
# total_min : 0.00000
# total_max : 0.07787
# Stopping : stop condition reached
# run evomol optimization
# SYMBOLS LIST : ['C', 'N', 'O', 'F']
# objective_calls
# Computing scores at initialization...
# Start pop algorithm
# EI_mean : 0.00000
# EI_med : 0.00000
# EI_std : 0.00000
# EI_min : 0.00000
# EI_max : 0.00000
# total_mean : 0.00000
# total_med : 0.00000
# total_std : 0.00000
# total_min : 0.00000
# total_max : 0.00000
# new step
# step : 0
# best : NCCCCC(N)=CO
# EI_mean : 0.00487
# EI_med : 0.00000
# EI_std : 0.01082
# EI_min : 0.00000
# EI_max : 0.03589
# total_mean : 0.00487
# total_med : 0.00000
# total_std : 0.01082
# total_min : 0.00000
# total_max : 0.03589
# new step
# step : 1
# best : NCCCC(O)=C(O)O
# EI_mean : 0.00346
# EI_med : 0.00000
# EI_std : 0.00908
# EI_min : 0.00000
# EI_max : 0.03589
# total_mean : 0.00346
# total_med : 0.00000
# total_std : 0.00908
# total_min : 0.00000
# total_max : 0.03589
# new step
# step : 2
# best : NCCCC(O)=C(O)O
# EI_mean : 0.00328
# EI_med : 0.00002
# EI_std : 0.00800
# EI_min : 0.00000
# EI_max : 0.03589
# total_mean : 0.00328
# total_med : 0.00002
# total_std : 0.00800
# total_min : 0.00000
# total_max : 0.03589
# new step
# step : 3
# best : NCCCC(O)=C(O)O
# EI_mean : 0.00396
# EI_med : 0.00005
# EI_std : 0.00831
# EI_min : 0.00000
# EI_max : 0.03589
# total_mean : 0.00396
# total_med : 0.00005
# total_std : 0.00831
# total_min : 0.00000
# total_max : 0.03589
# new step
# step : 4
# best : NCCCC(O)=C(O)O
# EI_mean : 0.00625
# EI_med : 0.00024
# EI_std : 0.01545
# EI_min : 0.00000
# EI_max : 0.08629
# total_mean : 0.00625
# total_med : 0.00024
# total_std : 0.01545
# total_min : 0.00000
# total_max : 0.08629
# new step
# step : 5
# best : NCCCC(O)=C(N)O
# EI_mean : 0.00642
# EI_med : 0.00040
# EI_std : 0.01498
# EI_min : 0.00000
# EI_max : 0.08629
# total_mean : 0.00642
# total_med : 0.00040
# total_std : 0.01498
# total_min : 0.00000
# total_max : 0.08629
# new step
# step : 6
# best : NCCCC(O)=C(N)O
# EI_mean : 0.00702
# EI_med : 0.00070
# EI_std : 0.01510
# EI_min : 0.00000
# EI_max : 0.08629
# total_mean : 0.00702
# total_med : 0.00070
# total_std : 0.01510
# total_min : 0.00000
# total_max : 0.08629
# new step
# step : 7
# best : NCCCC(O)=C(N)O
# EI_mean : 0.00865
# EI_med : 0.00159
# EI_std : 0.02184
# EI_min : 0.00000
# EI_max : 0.16391
# total_mean : 0.00865
# total_med : 0.00159
# total_std : 0.02184
# total_min : 0.00000
# total_max : 0.16391
# new step
# step : 8
# best : NCCC(N)C(O)=CO
# EI_mean : 0.00912
# EI_med : 0.00218
# EI_std : 0.02184
# EI_min : 0.00000
# EI_max : 0.16391
# total_mean : 0.00912
# total_med : 0.00218
# total_std : 0.02184
# total_min : 0.00000
# total_max : 0.16391
# new step
# step : 9
# best : NCCC(N)C(O)=CO
# EI_mean : 0.01072
# EI_med : 0.00273
# EI_std : 0.02613
# EI_min : 0.00000
# EI_max : 0.17322
# total_mean : 0.01072
# total_med : 0.00273
# total_std : 0.02613
# total_min : 0.00000
# total_max : 0.17322
# Stopping : stop condition reached
# run evomol optimization
# SYMBOLS LIST : ['C', 'N', 'O', 'F']
# objective_calls
# Computing scores at initialization...
# Start pop algorithm
# EI_mean : 0.00000
# EI_med : 0.00000
# EI_std : 0.00000
# EI_min : 0.00000
# EI_max : 0.00000
# total_mean : 0.00000
# total_med : 0.00000
# total_std : 0.00000
# total_min : 0.00000
# total_max : 0.00000
# new step
# step : 0
# best : C=CC(N)NCC(N)O
# EI_mean : 0.00763
# EI_med : 0.00000
# EI_std : 0.02493
# EI_min : 0.00000
# EI_max : 0.11403
# total_mean : 0.00763
# total_med : 0.00000
# total_std : 0.02493
# total_min : 0.00000
# total_max : 0.11403
# new step
# step : 1
# best : NCCCNCCCO
# EI_mean : 0.00522
# EI_med : 0.00000
# EI_std : 0.02064
# EI_min : 0.00000
# EI_max : 0.11403
# total_mean : 0.00522
# total_med : 0.00000
# total_std : 0.02064
# total_min : 0.00000
# total_max : 0.11403
# new step
# step : 2
# best : NCCCNCCCO
# EI_mean : 0.00525
# EI_med : 0.00004
# EI_std : 0.01825
# EI_min : 0.00000
# EI_max : 0.11403
# total_mean : 0.00525
# total_med : 0.00004
# total_std : 0.01825
# total_min : 0.00000
# total_max : 0.11403
# new step
# step : 3
# best : NCCCNCCCO
# EI_mean : 0.00564
# EI_med : 0.00033
# EI_std : 0.01675
# EI_min : 0.00000
# EI_max : 0.11403
# total_mean : 0.00564
# total_med : 0.00033
# total_std : 0.01675
# total_min : 0.00000
# total_max : 0.11403
# new step
# step : 4
# best : NCCCNCCCO
# EI_mean : 0.00533
# EI_med : 0.00039
# EI_std : 0.01546
# EI_min : 0.00000
# EI_max : 0.11403
# total_mean : 0.00533
# total_med : 0.00039
# total_std : 0.01546
# total_min : 0.00000
# total_max : 0.11403
# new step
# step : 5
# best : NCCCNCCCO
# EI_mean : 0.00479
# EI_med : 0.00041
# EI_std : 0.01440
# EI_min : 0.00000
# EI_max : 0.11403
# total_mean : 0.00479
# total_med : 0.00041
# total_std : 0.01440
# total_min : 0.00000
# total_max : 0.11403
# new step
# step : 6
# best : NCCCNCCCO
# EI_mean : 0.00505
# EI_med : 0.00051
# EI_std : 0.01390
# EI_min : 0.00000
# EI_max : 0.11403
# total_mean : 0.00505
# total_med : 0.00051
# total_std : 0.01390
# total_min : 0.00000
# total_max : 0.11403
# new step
# step : 7
# best : NCCCNCCCO
# EI_mean : 0.00494
# EI_med : 0.00058
# EI_std : 0.01333
# EI_min : 0.00000
# EI_max : 0.11403
# total_mean : 0.00494
# total_med : 0.00058
# total_std : 0.01333
# total_min : 0.00000
# total_max : 0.11403
# new step
# step : 8
# best : NCCCNCCCO
# EI_mean : 0.00470
# EI_med : 0.00051
# EI_std : 0.01278
# EI_min : 0.00000
# EI_max : 0.11403
# total_mean : 0.00470
# total_med : 0.00051
# total_std : 0.01278
# total_min : 0.00000
# total_max : 0.11403
# new step
# step : 9
# best : NCCCNCCCO
# EI_mean : 0.00437
# EI_med : 0.00047
# EI_std : 0.01223
# EI_min : 0.00000
# EI_max : 0.11403
# total_mean : 0.00437
# total_med : 0.00047
# total_std : 0.01223
# total_min : 0.00000
# total_max : 0.11403
# Stopping : stop condition reached
# run evomol optimization
# SYMBOLS LIST : ['C', 'N', 'O', 'F']
# objective_calls
# Computing scores at initialization...
# Start pop algorithm
# EI_mean : 0.00000
# EI_med : 0.00000
# EI_std : 0.00000
# EI_min : 0.00000
# EI_max : 0.00000
# total_mean : 0.00000
# total_med : 0.00000
# total_std : 0.00000
# total_min : 0.00000
# total_max : 0.00000
# new step
# step : 0
# best : NC(=CO)C(N)(O)CO
# EI_mean : 0.00189
# EI_med : 0.00000
# EI_std : 0.00495
# EI_min : 0.00000
# EI_max : 0.02220
# total_mean : 0.00189
# total_med : 0.00000
# total_std : 0.00495
# total_min : 0.00000
# total_max : 0.02220
# new step
# step : 1
# best : CC(N)=C(CO)OCN
# EI_mean : 0.00212
# EI_med : 0.00001
# EI_std : 0.00461
# EI_min : 0.00000
# EI_max : 0.02220
# total_mean : 0.00212
# total_med : 0.00001
# total_std : 0.00461
# total_min : 0.00000
# total_max : 0.02220
# new step
# step : 2
# best : CC(N)=C(CO)OCN
# EI_mean : 0.00172
# EI_med : 0.00004
# EI_std : 0.00406
# EI_min : 0.00000
# EI_max : 0.02220
# total_mean : 0.00172
# total_med : 0.00004
# total_std : 0.00406
# total_min : 0.00000
# total_max : 0.02220
# new step
# step : 3
# best : CC(N)=C(CO)OCN
# EI_mean : 0.00263
# EI_med : 0.00016
# EI_std : 0.00648
# EI_min : 0.00000
# EI_max : 0.03861
# total_mean : 0.00263
# total_med : 0.00016
# total_std : 0.00648
# total_min : 0.00000
# total_max : 0.03861
# new step
# step : 4
# best : CC(NCN)=C(O)CO
# EI_mean : 0.00347
# EI_med : 0.00052
# EI_std : 0.00771
# EI_min : 0.00000
# EI_max : 0.03861
# total_mean : 0.00347
# total_med : 0.00052
# total_std : 0.00771
# total_min : 0.00000
# total_max : 0.03861
# new step
# step : 5
# best : CC(NCN)=C(O)CO
# EI_mean : 0.00351
# EI_med : 0.00041
# EI_std : 0.00765
# EI_min : 0.00000
# EI_max : 0.03861
# total_mean : 0.00351
# total_med : 0.00041
# total_std : 0.00765
# total_min : 0.00000
# total_max : 0.03861
# new step
# step : 6
# best : CC(NCN)=C(O)CO
# EI_mean : 0.00705
# EI_med : 0.00054
# EI_std : 0.02466
# EI_min : 0.00000
# EI_max : 0.21203
# total_mean : 0.00705
# total_med : 0.00054
# total_std : 0.02466
# total_min : 0.00000
# total_max : 0.21203
# new step
# step : 7
# best : NCNCC=C(O)CO
# EI_mean : 0.00983
# EI_med : 0.00056
# EI_std : 0.03726
# EI_min : 0.00000
# EI_max : 0.28402
# total_mean : 0.00983
# total_med : 0.00056
# total_std : 0.03726
# total_min : 0.00000
# total_max : 0.28402
# new step
# step : 8
# best : NCCNCC=CCO
# EI_mean : 0.01344
# EI_med : 0.00075
# EI_std : 0.04955
# EI_min : 0.00000
# EI_max : 0.35645
# total_mean : 0.01344
# total_med : 0.00075
# total_std : 0.04955
# total_min : 0.00000
# total_max : 0.35645
# new step
# step : 9
# best : CC=C(O)CNCCN
# EI_mean : 0.01261
# EI_med : 0.00076
# EI_std : 0.04735
# EI_min : 0.00000
# EI_max : 0.35645
# total_mean : 0.01261
# total_med : 0.00076
# total_std : 0.04735
# total_min : 0.00000
# total_max : 0.35645
# Stopping : stop condition reached
# run evomol optimization
# SYMBOLS LIST : ['C', 'N', 'O', 'F']
# objective_calls
# Computing scores at initialization...
# Start pop algorithm
# EI_mean : 0.00000
# EI_med : 0.00000
# EI_std : 0.00000
# EI_min : 0.00000
# EI_max : 0.00000
# total_mean : 0.00000
# total_med : 0.00000
# total_std : 0.00000
# total_min : 0.00000
# total_max : 0.00000
# new step
# step : 0
# best : NC(O)C(N)C(N)CO
# EI_mean : 0.00078
# EI_med : 0.00000
# EI_std : 0.00325
# EI_min : 0.00000
# EI_max : 0.01492
# total_mean : 0.00078
# total_med : 0.00000
# total_std : 0.00325
# total_min : 0.00000
# total_max : 0.01492
# new step
# step : 1
# best : NCCC(N)(CN)CO
# EI_mean : 0.00269
# EI_med : 0.00000
# EI_std : 0.01122
# EI_min : 0.00000
# EI_max : 0.06134
# total_mean : 0.00269
# total_med : 0.00000
# total_std : 0.01122
# total_min : 0.00000
# total_max : 0.06134
# new step
# step : 2
# best : NCCCC(N)=C(N)O
# EI_mean : 0.00266
# EI_med : 0.00000
# EI_std : 0.00997
# EI_min : 0.00000
# EI_max : 0.06134
# total_mean : 0.00266
# total_med : 0.00000
# total_std : 0.00997
# total_min : 0.00000
# total_max : 0.06134
# new step
# step : 3
# best : NCCCC(N)=C(N)O
# EI_mean : 0.00287
# EI_med : 0.00004
# EI_std : 0.00981
# EI_min : 0.00000
# EI_max : 0.06134
# total_mean : 0.00287
# total_med : 0.00004
# total_std : 0.00981
# total_min : 0.00000
# total_max : 0.06134
# new step
# step : 4
# best : NCCCC(N)=C(N)O
# EI_mean : 0.00308
# EI_med : 0.00015
# EI_std : 0.00909
# EI_min : 0.00000
# EI_max : 0.06134
# total_mean : 0.00308
# total_med : 0.00015
# total_std : 0.00909
# total_min : 0.00000
# total_max : 0.06134
# new step
# step : 5
# best : NCCCC(N)=C(N)O
# EI_mean : 0.00443
# EI_med : 0.00025
# EI_std : 0.01353
# EI_min : 0.00000
# EI_max : 0.09129
# total_mean : 0.00443
# total_med : 0.00025
# total_std : 0.01353
# total_min : 0.00000
# total_max : 0.09129
# new step
# step : 6
# best : NCCC(CN)=C(N)O
# EI_mean : 0.00493
# EI_med : 0.00041
# EI_std : 0.01332
# EI_min : 0.00000
# EI_max : 0.09129
# total_mean : 0.00493
# total_med : 0.00041
# total_std : 0.01332
# total_min : 0.00000
# total_max : 0.09129
# new step
# step : 7
# best : NCCC(CN)=C(N)O
# EI_mean : 0.00514
# EI_med : 0.00044
# EI_std : 0.01284
# EI_min : 0.00000
# EI_max : 0.09129
# total_mean : 0.00514
# total_med : 0.00044
# total_std : 0.01284
# total_min : 0.00000
# total_max : 0.09129
# new step
# step : 8
# best : NCCC(CN)=C(N)O
# EI_mean : 0.00551
# EI_med : 0.00049
# EI_std : 0.01275
# EI_min : 0.00000
# EI_max : 0.09129
# total_mean : 0.00551
# total_med : 0.00049
# total_std : 0.01275
# total_min : 0.00000
# total_max : 0.09129
# new step
# step : 9
# best : NCCC(CN)=C(N)O
# EI_mean : 0.00525
# EI_med : 0.00053
# EI_std : 0.01222
# EI_min : 0.00000
# EI_max : 0.09129
# total_mean : 0.00525
# total_med : 0.00053
# total_std : 0.01222
# total_min : 0.00000
# total_max : 0.09129
# Stopping : stop condition reached
# ['NCC=C(O)CC(N)F', 'CC=C(O)CNCCN', 'NCCN1CCNCC1', 'NCC=C(O)C(N)N', 'NC(O)=C1CNCCN1', 'NCCC(CN)=C(N)O', 'NCNOC=COCO', 'NCC(O)=COCCO', 'NCC1=C2COC(O1)O2', 'NCCCNCCCO']
# computing dft for NCC=C(O)CC(N)F
# Starting OPT
# Execution time OPT: 201s
# There are 20 atoms and 103 MOs
# computing dft for CC=C(O)CNCCN
# Starting OPT
# Execution time OPT: 148s
# There are 23 atoms and 109 MOs
# computing dft for NCCN1CCNCC1
# Starting OPT

# %%
# Running 10 executions

# for i in range(10):
#     run(i)
