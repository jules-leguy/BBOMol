# %%
import os

# Paths
results_path = "output/01_EA_baseline"
dft_path = os.path.abspath("output/dft_files")

# EA parameters
pop_max_size = 300
n_to_replace = 10
record_all_generated_individuals = True
problem_type = "max"

# EA I/O parameters
save_n_steps = 1

# EA stop criterion
max_steps = float("inf")
max_obj_calls = 1000

# Initial population initialization
init_smi = ["C"]

# QM objective and MM starting point
prop = "homo"
MM_program = "rdkit"

# Chemical space
atoms = "C,N,O,F"
max_heavy_atoms = 9

# Parallelization (None)
dft_n_threads = 1

# %%
from evomol import run_model
from os.path import join
from evomol.evaluation_dft import OPTEvaluationStrategy

def run(i):
        
    run_model({
        "obj_function": OPTEvaluationStrategy(
                            prop=prop,
                            n_jobs=dft_n_threads,
                            working_dir_path=dft_path,
                            MM_program=MM_program,
                          ),
        "optimization_parameters": {
            "max_steps": max_steps,
            "max_obj_calls": max_obj_calls,
            "pop_max_size": pop_max_size,
            "k_to_replace": n_to_replace,
            "problem_type": problem_type,
        },
        "io_parameters": {
            "model_path": join(results_path, str(i)),
            "smiles_list_init": init_smi,
            "save_n_steps": save_n_steps,
            "record_all_generated_individuals": record_all_generated_individuals
        },
        "action_space_parameters": {
            "atoms": atoms,
            "max_heavy_atoms": max_heavy_atoms,
        }
    })

# %%
# Running a single execution

run(0)
# Out:
# 0 molecules in cache
# SYMBOLS LIST : ['C', 'N', 'O', 'F']
# objective_calls
# Computing scores at initialization...
# computing dft for C
# Starting OPT
# Execution time OPT: 1s
# There are 5 atoms and 17 MOs
# Start pop algorithm
# homo_mean : -10.58115
# homo_med : -10.58115
# homo_std : 0.00000
# homo_min : -10.58115
# homo_max : -10.58115
# lumo_mean : 3.97014
# lumo_med : 3.97014
# lumo_std : 0.00000
# lumo_min : 3.97014
# lumo_max : 3.97014
# gap_mean : 14.55129
# gap_med : 14.55129
# gap_std : 0.00000
# gap_min : 14.55129
# gap_max : 14.55129
# total_mean : -10.58115
# total_med : -10.58115
# total_std : 0.00000
# total_min : -10.58115
# total_max : -10.58115
# new step
# step : 0
# best : C
# computing dft for
# MM error (Evaluation error)
# No replacement occurred
# homo_mean : -10.58115
# homo_med : -10.58115
# homo_std : 0.00000
# homo_min : -10.58115
# homo_max : -10.58115
# lumo_mean : 3.97014
# lumo_med : 3.97014
# lumo_std : 0.00000
# lumo_min : 3.97014
# lumo_max : 3.97014
# gap_mean : 14.55129
# gap_med : 14.55129
# gap_std : 0.00000
# gap_min : 14.55129
# gap_max : 14.55129
# total_mean : -10.58115
# total_med : -10.58115
# total_std : 0.00000
# total_min : -10.58115
# total_max : -10.58115
# new step
# step : 1
# best : C
# computing dft for N
# Starting OPT
# Execution time OPT: 3s
# There are 4 atoms and 15 MOs
# homo_mean : -8.12790
# homo_med : -8.12790
# homo_std : 2.45324
# homo_min : -10.58115
# homo_max : -5.67466
# lumo_mean : 3.50578
# lumo_med : 3.50578
# lumo_std : 0.46436
# lumo_min : 3.04142
# lumo_max : 3.97014
# gap_mean : 11.63368
# gap_med : 11.63368
# gap_std : 2.91760
# gap_min : 8.71608
# gap_max : 14.55129
# total_mean : -8.12790
# total_med : -8.12790
# total_std : 2.45324
# total_min : -10.58115
# total_max : -5.67466
# new step
# step : 2
# best : N
# computing dft for
# MM error (Evaluation error)
# computing dft for F
# MM error (Evaluation error)
# No replacement occurred
# homo_mean : -8.12790
# homo_med : -8.12790
# homo_std : 2.45324
# homo_min : -10.58115
# homo_max : -5.67466
# lumo_mean : 3.50578
# lumo_med : 3.50578
# lumo_std : 0.46436
# lumo_min : 3.04142
# lumo_max : 3.97014
# gap_mean : 11.63368
# gap_med : 11.63368
# gap_std : 2.91760
# gap_min : 8.71608
# gap_max : 14.55129
# total_mean : -8.12790
# total_med : -8.12790
# total_std : 2.45324
# total_min : -10.58115
# total_max : -5.67466
# new step
# step : 3
# best : N
# computing dft for O
# Starting OPT
# Execution time OPT: 2s
# There are 3 atoms and 13 MOs
# computing dft for NF
# Starting OPT
# Execution time OPT: 4s
# There are 4 atoms and 22 MOs
# homo_mean : -7.52109
# homo_med : -6.91428
# homo_std : 1.83854
# homo_min : -10.58115
# homo_max : -5.67466
# lumo_mean : 2.56780
# lumo_med : 2.70944
# lumo_std : 1.12565
# lumo_min : 0.88219
# lumo_max : 3.97014
# gap_mean : 10.08889
# gap_med : 9.04139
# gap_std : 2.64214
# gap_min : 7.72150
# gap_max : 14.55129
# total_mean : -7.52109
# total_med : -6.91428
# total_std : 1.83854
# total_min : -10.58115
# total_max : -5.67466
# new step
# step : 4
# best : N
# computing dft for N#N
# MM error (Evaluation error)
# computing dft for NN
# Starting OPT
# Execution time OPT: 8s
# There are 6 atoms and 26 MOs
# computing dft for CCO
# Starting OPT
# Execution time OPT: 14s
# There are 9 atoms and 39 MOs
# computing dft for
# MM error (Evaluation error)
# homo_mean : -7.07623
# homo_med : -6.74734
# homo_std : 1.65002
# homo_min : -10.58115
# homo_max : -5.67466
# lumo_mean : 2.63638
# lumo_med : 2.77352
# lumo_std : 0.92822
# lumo_min : 0.88219
# lumo_max : 3.97014
# gap_mean : 9.71261
# gap_med : 8.99772
# gap_std : 2.22960
# gap_min : 7.72150
# gap_max : 14.55129
# total_mean : -7.07623
# total_med : -6.74734
# total_std : 1.65002
# total_min : -10.58115
# total_max : -5.67466
# new step
# step : 5
# best : N
# computing dft for
# MM error (Evaluation error)
# computing dft for NNO
# Starting OPT
# Execution time OPT: 13s
# There are 7 atoms and 35 MOs
# computing dft for NCCO
# Starting OPT
# Execution time OPT: 25s
# There are 11 atoms and 50 MOs
# computing dft for CNF
# Starting OPT
# Execution time OPT: 13s
# There are 7 atoms and 35 MOs
# computing dft for
# MM error (Evaluation error)
# computing dft for F
# MM error (Evaluation error)
# homo_mean : -6.78189
# homo_med : -6.57999
# homo_std : 1.43369
# homo_min : -10.58115
# homo_max : -5.56391
# lumo_mean : 2.34843
# lumo_med : 2.37746
# lumo_std : 0.91735
# lumo_min : 0.88219
# lumo_max : 3.97014
# gap_mean : 9.13033
# gap_med : 8.64070
# gap_std : 2.00931
# gap_min : 7.58681
# gap_max : 14.55129
# total_mean : -6.78189
# total_med : -6.57999
# total_std : 1.43369
# total_min : -10.58115
# total_max : -5.56391
# new step
# step : 6
# best : NCCO
# computing dft for CCNO
# Starting OPT
# Execution time OPT: 25s
# There are 11 atoms and 50 MOs
# computing dft for CN
# Starting OPT
# Execution time OPT: 8s
# There are 7 atoms and 28 MOs
# computing dft for CNN
# Starting OPT
# Execution time OPT: 17s
# There are 9 atoms and 39 MOs
# computing dft for NO
# Starting OPT
# Execution time OPT: 5s
# There are 5 atoms and 24 MOs
# computing dft for CNCF
# Starting OPT
# Execution time OPT: 65s
# There are 10 atoms and 48 MOs
# computing dft for CCOC
# Starting OPT
# Execution time OPT: 15s
# There are 12 atoms and 52 MOs
# computing dft for F
# MM error (Evaluation error)
# computing dft for
# MM error (Evaluation error)
# computing dft for
# MM error (Evaluation error)
# homo_mean : -6.48683
# homo_med : -6.35440
# homo_std : 1.18824
# homo_min : -10.58115
# homo_max : -5.45425
# lumo_mean : 2.49369
# lumo_med : 2.62399
# lumo_std : 0.77365
# lumo_min : 0.88219
# lumo_max : 3.97014
# gap_mean : 8.98052
# gap_med : 8.59009
# gap_std : 1.58992
# gap_min : 7.58681
# gap_max : 14.55129
# total_mean : -6.48683
# total_med : -6.35440
# total_std : 1.18824
# total_min : -10.58115
# total_max : -5.45425
# new step
# step : 7
# best : CN
# computing dft for C#N
# Starting OPT
# Execution time OPT: 2s
# There are 3 atoms and 20 MOs
# computing dft for CCN
# Starting OPT
# Execution time OPT: 19s
# There are 10 atoms and 41 MOs
# computing dft for
# MM error (Evaluation error)
# computing dft for NCO
# Starting OPT
# Execution time OPT: 73s
# There are 8 atoms and 37 MOs
# computing dft for CCN=N
# MM error (Evaluation error)
# computing dft for C1=NOC1
# MM error (Evaluation error)
# computing dft for CN(C)F
# Starting OPT
# Execution time OPT: 23s
# There are 10 atoms and 48 MOs
# computing dft for NOO
# Starting OPT
# Execution time OPT: 39s
# DFT error : Error during OPT for NOO (Evaluation error)
# computing dft for CCOCC
# Starting OPT
# Execution time OPT: 45s
# There are 15 atoms and 65 MOs
# computing dft for N=O
# Starting OPT
# Execution time OPT: 3s
# There are 3 atoms and 20 MOs
# computing dft for CN(N)F
# Starting OPT
# Execution time OPT: 23s
# There are 9 atoms and 46 MOs
# computing dft for COC
# Starting OPT
# Execution time OPT: 9s
# There are 9 atoms and 39 MOs
# computing dft for F
# MM error (Evaluation error)
# computing dft for CO
# Starting OPT
# Execution time OPT: 6s
# There are 6 atoms and 26 MOs
# computing dft for F
# MM error (Evaluation error)
# homo_mean : -6.57881
# homo_med : -6.39808
# homo_std : 1.18581
# homo_min : -10.58115
# homo_max : -5.45425
# lumo_mean : 2.14853
# lumo_med : 2.61651
# lumo_std : 1.35390
# lumo_min : -2.91380
# lumo_max : 3.97014
# gap_mean : 8.72734
# gap_med : 8.61540
# gap_std : 1.75893
# gap_min : 3.51027
# gap_max : 14.55129
# total_mean : -6.57881
# total_med : -6.39808
# total_std : 1.18581
# total_min : -10.58115
# total_max : -5.45425
# new step
# step : 8
# best : CN
# computing dft for CF
# Starting OPT
# Execution time OPT: 5s
# There are 5 atoms and 24 MOs
# computing dft for CCCN
# Starting OPT
# Execution time OPT: 39s
# There are 13 atoms and 54 MOs
# computing dft for CC(C)O
# Starting OPT
# Execution time OPT: 23s
# There are 12 atoms and 52 MOs
# computing dft for
# MM error (Evaluation error)
# computing dft for N=N
# Starting OPT
# Execution time OPT: 4s
# There are 4 atoms and 22 MOs
# computing dft for CC(O)NN
# Starting OPT
# Execution time OPT: 46s
# There are 13 atoms and 61 MOs
# computing dft for CON
# Starting OPT
# Execution time OPT: 10s
# There are 8 atoms and 37 MOs
# computing dft for CN=O
# MM error (Evaluation error)
# computing dft for FC1=CN1
# MM error (Evaluation error)
# computing dft for CNO
# Starting OPT
# Execution time OPT: 13s
# There are 8 atoms and 37 MOs
# computing dft for CCOCCCF
# Starting OPT
# Execution time OPT: 96s
# There are 18 atoms and 85 MOs
# computing dft for OCNF
# Starting OPT
# Execution time OPT: 19s
# There are 8 atoms and 44 MOs
# computing dft for COCCN
# Starting OPT
# Execution time OPT: 33s
# There are 14 atoms and 63 MOs
# homo_mean : -6.54184
# homo_med : -6.37767
# homo_std : 1.08958
# homo_min : -10.58115
# homo_max : -5.45425
# lumo_mean : 2.11260
# lumo_med : 2.61651
# lumo_std : 1.36498
# lumo_min : -2.91380
# lumo_max : 3.97014
# gap_mean : 8.65444
# gap_med : 8.57404
# gap_std : 1.73258
# gap_min : 3.51027
# gap_max : 14.55129
# total_mean : -6.54184
# total_med : -6.37767
# total_std : 1.08958
# total_min : -10.58115
# total_max : -5.45425
# new step
# step : 9
# best : CN
# computing dft for C=NN
# MM error (Evaluation error)
# computing dft for C#C
# Starting OPT
# Execution time OPT: 4s
# There are 4 atoms and 22 MOs
# computing dft for NC(N)O
# Starting OPT
# Execution time OPT: 48s
# There are 10 atoms and 48 MOs
# computing dft for CC(C)N
# Starting OPT
# Execution time OPT: 32s
# There are 13 atoms and 54 MOs
# computing dft for COCC(N)F
# Starting OPT
# Execution time OPT: 88s
# There are 14 atoms and 70 MOs
# computing dft for
# MM error (Evaluation error)
# computing dft for NCN
# Starting OPT
# Execution time OPT: 20s
# There are 9 atoms and 39 MOs
# computing dft for NC1=NN1
# MM error (Evaluation error)
# computing dft for CC(O)CN
# Starting OPT
# Execution time OPT: 54s
# There are 14 atoms and 63 MOs
# computing dft for CN=O
# MM error (Evaluation error)
# computing dft for CN(O)O
# Starting OPT
# Execution time OPT: 19s
# There are 9 atoms and 46 MOs
# computing dft for NNCO
# Starting OPT
# Execution time OPT: 34s
# There are 10 atoms and 48 MOs
# computing dft for FCNF
# Starting OPT
# Execution time OPT: 14s
# There are 7 atoms and 42 MOs
# computing dft for N=CN
# MM error (Evaluation error)
# computing dft for NOF
# Starting OPT
# Execution time OPT: 11s
# There are 5 atoms and 31 MOs
# homo_mean : -6.49156
# homo_med : -6.36502
# homo_std : 1.05715
# homo_min : -10.58115
# homo_max : -5.31738
# lumo_mean : 2.04503
# lumo_med : 2.54168
# lumo_std : 1.35502
# lumo_min : -2.91380
# lumo_max : 3.97014
# gap_mean : 8.53659
# gap_med : 8.50710
# gap_std : 1.58722
# gap_min : 3.51027
# gap_max : 14.55129
# total_mean : -6.49156
# total_med : -6.36502
# total_std : 1.05715
# total_min : -10.58115
# total_max : -5.31738
# new step
# step : 10
# best : CC(O)CN
# computing dft for NCCCO
# Starting OPT
# Execution time OPT: 50s
# There are 14 atoms and 63 MOs
# computing dft for N#CO
# Starting OPT
# Execution time OPT: 5s
# There are 4 atoms and 29 MOs
# computing dft for CC
# Starting OPT
# Execution time OPT: 6s
# There are 8 atoms and 30 MOs
# computing dft for NC(N)CO
# Starting OPT
# Execution time OPT: 50s
# There are 13 atoms and 61 MOs
# computing dft for CNC
# Starting OPT
# Execution time OPT: 16s
# There are 10 atoms and 41 MOs
# computing dft for CCCC(C)N
# Starting OPT
# Execution time OPT: 61s
# There are 19 atoms and 80 MOs
# computing dft for CNCCCO
# Starting OPT
# Execution time OPT: 52s
# There are 17 atoms and 76 MOs
# computing dft for NC(F)CO
# Starting OPT
# Execution time OPT: 58s
# There are 11 atoms and 57 MOs
# computing dft for COCN
# Starting OPT
# Execution time OPT: 21s
# There are 11 atoms and 50 MOs
# computing dft for NCF
# Starting OPT
# Execution time OPT: 25s
# There are 7 atoms and 35 MOs
# homo_mean : -6.48456
# homo_med : -6.35563
# homo_std : 1.09427
# homo_min : -10.58115
# homo_max : -5.31330
# lumo_mean : 2.14679
# lumo_med : 2.58617
# lumo_std : 1.29150
# lumo_min : -2.91380
# lumo_max : 3.97014
# gap_mean : 8.63135
# gap_med : 8.50710
# gap_std : 1.56166
# gap_min : 3.51027
# gap_max : 14.55129
# total_mean : -6.48456
# total_med : -6.35563
# total_std : 1.09427
# total_min : -10.58115
# total_max : -5.31330
# new step
# step : 11
# best : CNC
# computing dft for CCNC
# Starting OPT
# Execution time OPT: 25s
# There are 13 atoms and 54 MOs
# computing dft for CCCCN
# Starting OPT
# Execution time OPT: 37s
# There are 16 atoms and 67 MOs
# computing dft for NCCNN
# Starting OPT
# Execution time OPT: 56s
# There are 14 atoms and 63 MOs
# computing dft for C=N
# Starting OPT
# Execution time OPT: 4s
# There are 5 atoms and 24 MOs
# computing dft for NC(N)OO
# Starting OPT
# Execution time OPT: 58s
# There are 11 atoms and 57 MOs
# computing dft for CNCC1=CO1
# Starting OPT
# Execution time OPT: 319s
# Python argument types in
#     rdkit.Chem.rdmolops.RemoveStereochemistry(NoneType)
# did not match C++ signature:
#     RemoveStereochemistry(RDKit::ROMol {lvalue} mol)
# computing dft for CC=N
# Starting OPT
# Execution time OPT: 10s
# There are 8 atoms and 37 MOs
# computing dft for CCC(C)N
# Starting OPT
# Execution time OPT: 46s
# There are 16 atoms and 67 MOs
# computing dft for CC(N)CO
# Starting OPT
# Execution time OPT: 45s
# There are 14 atoms and 63 MOs
# computing dft for NC=CCO
# Starting OPT
# Execution time OPT: 49s
# There are 12 atoms and 59 MOs
# computing dft for CC1=NC1
# MM error (Evaluation error)
# computing dft for CNCN
# Starting OPT
# Execution time OPT: 35s
# There are 12 atoms and 52 MOs
# homo_mean : -6.35303
# homo_med : -6.25399
# homo_std : 1.07391
# homo_min : -10.58115
# homo_max : -4.88825
# lumo_mean : 2.12480
# lumo_med : 2.58263
# lumo_std : 1.26702
# lumo_min : -2.91380
# lumo_max : 3.97014
# gap_mean : 8.47782
# gap_med : 8.42873
# gap_std : 1.50767
# gap_min : 3.51027
# gap_max : 14.55129
# total_mean : -6.35303
# total_med : -6.25399
# total_std : 1.07391
# total_min : -10.58115
# total_max : -4.88825
# new step
# step : 12
# best : NC=CCO
# computing dft for N=C=CCO
# MM error (Evaluation error)
# computing dft for CNCCNCN
# Starting OPT
# Execution time OPT: 120s
# There are 20 atoms and 89 MOs
# computing dft for CNCNO
# Starting OPT
# Execution time OPT: 40s
# There are 13 atoms and 61 MOs
# computing dft for CNCO
# Starting OPT
# Execution time OPT: 53s
# There are 11 atoms and 50 MOs
# computing dft for CC1(O)CN1
# Starting OPT
# Execution time OPT: 38s
# There are 12 atoms and 59 MOs
# computing dft for CCNCO
# Starting OPT
# Execution time OPT: 54s
# There are 14 atoms and 63 MOs
# computing dft for NCCN
# Starting OPT
# Execution time OPT: 30s
# There are 12 atoms and 52 MOs
# computing dft for ONF
# Starting OPT
# Execution time OPT: 12s
# There are 5 atoms and 31 MOs
# computing dft for NC(N)NO
# Starting OPT
# Execution time OPT: 50s
# There are 12 atoms and 59 MOs
# computing dft for CCCNC
# Starting OPT
# Execution time OPT: 43s
# There are 16 atoms and 67 MOs
# computing dft for CNCCO
# Starting OPT
# Execution time OPT: 43s
# There are 14 atoms and 63 MOs
# homo_mean : -6.25821
# homo_med : -6.08923
# homo_std : 1.04955
# homo_min : -10.58115
# homo_max : -4.88825
# lumo_mean : 2.15462
# lumo_med : 2.55637
# lumo_std : 1.20513
# lumo_min : -2.91380
# lumo_max : 3.97014
# gap_mean : 8.41283
# gap_med : 8.34056
# gap_std : 1.41725
# gap_min : 3.51027
# gap_max : 14.55129
# total_mean : -6.25821
# total_med : -6.08923
# total_std : 1.04955
# total_min : -10.58115
# total_max : -4.88825
# new step
# step : 13
# best : NC=CCO
# computing dft for C=CCO
# Starting OPT
# Execution time OPT: 26s
# There are 10 atoms and 48 MOs
# computing dft for CNC(CN)CN
# Starting OPT
# Execution time OPT: 97s
# There are 20 atoms and 89 MOs
# computing dft for CCNN
# Starting OPT
# Execution time OPT: 27s
# There are 12 atoms and 52 MOs
# computing dft for CN1CCCO1
# Starting OPT
# Execution time OPT: 187s
# There are 15 atoms and 72 MOs
# computing dft for NCCCNN
# Starting OPT
# Execution time OPT: 89s
# There are 17 atoms and 76 MOs
# computing dft for NC1CN1
# Starting OPT
# Execution time OPT: 37s
# There are 10 atoms and 48 MOs
# computing dft for CCC
# Starting OPT
# Execution time OPT: 13s
# There are 11 atoms and 43 MOs
# computing dft for c1[nH]c2cc1-2
# MM error (Evaluation error)
# computing dft for OC1C#CC1
# MM error (Evaluation error)
# computing dft for C1=CCC1
# Starting OPT
# Execution time OPT: 14s
# There are 10 atoms and 48 MOs
# computing dft for CC(N)N
# Starting OPT
# Execution time OPT: 43s
# There are 12 atoms and 52 MOs
# computing dft for C=NCO
# MM error (Evaluation error)
# computing dft for
# MM error (Evaluation error)
# computing dft for NCC(N)O
# Starting OPT
# Execution time OPT: 63s
# There are 13 atoms and 61 MOs
# homo_mean : -6.23517
# homo_med : -6.04501
# homo_std : 1.05347
# homo_min : -10.58115
# homo_max : -4.88825
# lumo_mean : 2.16590
# lumo_med : 2.58263
# lumo_std : 1.17644
# lumo_min : -2.91380
# lumo_max : 3.97014
# gap_mean : 8.40107
# gap_med : 8.30859
# gap_std : 1.40722
# gap_min : 3.51027
# gap_max : 14.55129
# total_mean : -6.23517
# total_med : -6.04501
# total_std : 1.05347
# total_min : -10.58115
# total_max : -4.88825
# new step
# step : 14
# best : NC=CCO
# computing dft for NC=CCCO
# Starting OPT
# Execution time OPT: 85s
# There are 15 atoms and 72 MOs
# computing dft for CNCC(N)NC
# Starting OPT
# Execution time OPT: 169s
# There are 20 atoms and 89 MOs
# computing dft for NCC1C(N)N1F
# Starting OPT
# Execution time OPT: 98s
# There are 15 atoms and 79 MOs
# computing dft for N=NCCN
# MM error (Evaluation error)
# computing dft for CCCOO
# Starting OPT
# Execution time OPT: 40s
# There are 13 atoms and 61 MOs
# computing dft for NCCCN
# Starting OPT
# Execution time OPT: 51s
# There are 15 atoms and 65 MOs
# computing dft for CNCCCN
# Starting OPT
# Execution time OPT: 79s
# There are 18 atoms and 78 MOs
# computing dft for CNC(C)F
# Starting OPT
# Execution time OPT: 51s
# There are 13 atoms and 61 MOs
# computing dft for CN1CC1
# Starting OPT
# Execution time OPT: 26s
# There are 11 atoms and 50 MOs
# computing dft for CC(N)F
# Starting OPT
# Execution time OPT: 60s
# There are 10 atoms and 48 MOs
# computing dft for CC=NC
# Starting OPT
# Execution time OPT: 154s
# There are 11 atoms and 50 MOs
# homo_mean : -6.17890
# homo_med : -5.98038
# homo_std : 1.02440
# homo_min : -10.58115
# homo_max : -4.86839
# lumo_mean : 2.16184
# lumo_med : 2.60549
# lumo_std : 1.16617
# lumo_min : -2.91380
# lumo_max : 3.97014
# gap_mean : 8.34074
# gap_med : 8.30437
# gap_std : 1.38924
# gap_min : 3.51027
# gap_max : 14.55129
# total_mean : -6.17890
# total_med : -5.98038
# total_std : 1.02440
# total_min : -10.58115
# total_max : -4.86839
# new step
# step : 15
# best : NC=CCCO
# computing dft for CCC=CN
# Starting OPT
# Execution time OPT: 76s
# There are 14 atoms and 63 MOs
# computing dft for NN=CCO
# Starting OPT
# Execution time OPT: 82s
# There are 11 atoms and 57 MOs
# computing dft for NCCNC1CN1
# Starting OPT
# Execution time OPT: 187s
# There are 18 atoms and 85 MOs
# computing dft for CCN(C)CN
# Starting OPT
# Execution time OPT: 129s
# There are 18 atoms and 78 MOs
# computing dft for NCNC(N)CNN
# Starting OPT
# Execution time OPT: 651s
# There are 21 atoms and 98 MOs
# computing dft for CNCCC(N)O
# Starting OPT
# Execution time OPT: 173s
# There are 19 atoms and 87 MOs
# computing dft for CNCCN
# Starting OPT
# Execution time OPT: 42s
# There are 15 atoms and 65 MOs
# computing dft for CC=NCO
# Starting OPT
# Execution time OPT: 82s
# There are 12 atoms and 59 MOs
# computing dft for NCCNO
# Starting OPT
# Execution time OPT: 71s
# There are 13 atoms and 61 MOs
# computing dft for CNC(C)N
# Starting OPT
# Execution time OPT: 265s
# There are 15 atoms and 65 MOs
# homo_mean : -6.10039
# homo_med : -5.77888
# homo_std : 1.01244
# homo_min : -10.58115
# homo_max : -4.65478
# lumo_mean : 2.15674
# lumo_med : 2.60549
# lumo_std : 1.15016
# lumo_min : -2.91380
# lumo_max : 3.97014
# gap_mean : 8.25712
# gap_med : 8.24083
# gap_std : 1.36886
# gap_min : 3.51027
# gap_max : 14.55129
# total_mean : -6.10039
# total_med : -5.77888
# total_std : 1.01244
# total_min : -10.58115
# total_max : -4.65478
# new step
# step : 16
# best : NCNC(N)CNN
# computing dft for NCNC(N)CN
# Starting OPT
# Execution time OPT: 135s
# There are 19 atoms and 87 MOs
# computing dft for COC=CN
# Starting OPT
# Execution time OPT: 47s
# There are 12 atoms and 59 MOs
# computing dft for CCCC=CN
# Starting OPT
# Execution time OPT: 86s
# There are 17 atoms and 76 MOs
# computing dft for CC=C=N
# MM error (Evaluation error)
# computing dft for CNCCCNCN
# Starting OPT
# Execution time OPT: 111s
# There are 23 atoms and 102 MOs
# computing dft for CNC(CN)CCN
# Starting OPT
# Execution time OPT: 174s
# There are 23 atoms and 102 MOs
# computing dft for NNCNC1CN1
# Starting OPT
# Execution time OPT: 100s
# There are 17 atoms and 83 MOs
# computing dft for CNCC(C)N
# Starting OPT
# Execution time OPT: 197s
# There are 18 atoms and 78 MOs
# computing dft for CC(C)CCN
# Starting OPT
# Execution time OPT: 56s
# There are 19 atoms and 80 MOs
# computing dft for NNCNO
# Starting OPT
# Execution time OPT: 36s
# There are 12 atoms and 59 MOs
# computing dft for CN(C)CO
# Starting OPT
# Execution time OPT: 39s
# There are 14 atoms and 63 MOs
# homo_mean : -6.02200
# homo_med : -5.73725
# homo_std : 1.00650
# homo_min : -10.58115
# homo_max : -4.48825
# lumo_mean : 2.18914
# lumo_med : 2.62522
# lumo_std : 1.11181
# lumo_min : -2.91380
# lumo_max : 3.97014
# gap_mean : 8.21115
# gap_med : 8.22396
# gap_std : 1.33030
# gap_min : 3.51027
# gap_max : 14.55129
# total_mean : -6.02200
# total_med : -5.73725
# total_std : 1.00650
# total_min : -10.58115
# total_max : -4.48825
# new step
# step : 17
# best : COC=CN
# computing dft for NC=COCN
# Starting OPT
# Execution time OPT: 200s
# There are 14 atoms and 70 MOs
# computing dft for NNCC(N)NCO
# Starting OPT
# Execution time OPT: 420s
# There are 20 atoms and 96 MOs
# computing dft for CC1=NC=C1
# MM error (Evaluation error)
# computing dft for CCC=CCNC
# Starting OPT
# Execution time OPT: 75s
# There are 20 atoms and 89 MOs
# computing dft for CC=CNCO
# MM error (Evaluation error)
# computing dft for CC=CN
# Starting OPT
# Execution time OPT: 50s
# There are 11 atoms and 50 MOs
# computing dft for CN1CC1(C)N
# Starting OPT
# Execution time OPT: 79s
# There are 16 atoms and 74 MOs
# computing dft for CNC1(CN)CN1
# Starting OPT
# Execution time OPT: 96s
# There are 18 atoms and 85 MOs
# computing dft for CNC(N)CCN
# Starting OPT
# Execution time OPT: 119s
# There are 20 atoms and 89 MOs
# computing dft for NCC(N)CN
# Starting OPT
# Execution time OPT: 69s
# There are 17 atoms and 76 MOs
# computing dft for C1CN2CC2N1
# Starting OPT
# Execution time OPT: 47s
# There are 14 atoms and 70 MOs
# computing dft for CNC(N)C(N)CF
# Starting OPT
# Execution time OPT: 128s
# There are 20 atoms and 96 MOs
# homo_mean : -5.95207
# homo_med : -5.70283
# homo_std : 1.00366
# homo_min : -10.58115
# homo_max : -4.06946
# lumo_mean : 2.20159
# lumo_med : 2.58753
# lumo_std : 1.07358
# lumo_min : -2.91380
# lumo_max : 3.97014
# gap_mean : 8.15366
# gap_med : 8.19457
# gap_std : 1.30373
# gap_min : 3.51027
# gap_max : 14.55129
# total_mean : -5.95207
# total_med : -5.70283
# total_std : 1.00366
# total_min : -10.58115
# total_max : -4.06946
# new step
# step : 18
# best : NC=COCN
# computing dft for NC=CCCN
# Starting OPT
# Execution time OPT: 116s
# There are 16 atoms and 74 MOs
# computing dft for C=COCCN
# Starting OPT
# Execution time OPT: 97s
# There are 15 atoms and 72 MOs
# computing dft for CNNC1N=NCN1
# MM error (Evaluation error)
# computing dft for C=C(C)N
# Starting OPT
# Execution time OPT: 56s
# There are 11 atoms and 50 MOs
# computing dft for CCCC=CNF
# Starting OPT
# Execution time OPT: 90s
# There are 17 atoms and 83 MOs
# computing dft for CCN=CN
# Starting OPT
# Execution time OPT: 58s
# There are 13 atoms and 61 MOs
# computing dft for NC=NCCO
# MM error (Evaluation error)
# computing dft for CC(O)=CN
# Starting OPT
# Execution time OPT: 88s
# There are 12 atoms and 59 MOs
# computing dft for NC1=CNC(N)C1O
# Starting OPT
# Execution time OPT: 382s
# There are 17 atoms and 90 MOs
# computing dft for CN(N)CCN
# Starting OPT
# Execution time OPT: 62s
# There are 17 atoms and 76 MOs
# computing dft for CNCCNC
# Starting OPT
# Execution time OPT: 58s
# There are 18 atoms and 78 MOs
# computing dft for NCCC1N=C1N
# MM error (Evaluation error)
# computing dft for NCCNCCN
# Starting OPT
# Execution time OPT: 85s
# There are 20 atoms and 89 MOs
# homo_mean : -5.89621
# homo_med : -5.67017
# homo_std : 0.99544
# homo_min : -10.58115
# homo_max : -4.06946
# lumo_mean : 2.16916
# lumo_med : 2.54821
# lumo_std : 1.06499
# lumo_min : -2.91380
# lumo_max : 3.97014
# gap_mean : 8.06537
# gap_med : 8.09280
# gap_std : 1.30897
# gap_min : 3.51027
# gap_max : 14.55129
# total_mean : -5.89621
# total_med : -5.67017
# total_std : 0.99544
# total_min : -10.58115
# total_max : -4.06946
# new step
# step : 19
# best : NC=COCN
# computing dft for NCOC=NN
# MM error (Evaluation error)
# computing dft for COCCCN
# Starting OPT
# Execution time OPT: 59s
# There are 17 atoms and 76 MOs
# computing dft for CC(O)CCN
# Starting OPT
# Execution time OPT: 84s
# There are 17 atoms and 76 MOs
# computing dft for NC1=CNCC1O
# Starting OPT
# Execution time OPT: 84s
# There are 15 atoms and 79 MOs
# computing dft for NCNC(N)CNNO
# Starting OPT
# Execution time OPT: 144s
# There are 22 atoms and 107 MOs
# computing dft for CC=NN
# MM error (Evaluation error)
# computing dft for C=CC=CN
# Starting OPT
# Execution time OPT: 39s
# There are 12 atoms and 59 MOs
# computing dft for CCC=CO
# Starting OPT
# Execution time OPT: 33s
# There are 13 atoms and 61 MOs
# computing dft for C=CCCN
# Starting OPT
# Execution time OPT: 38s
# There are 14 atoms and 63 MOs
# computing dft for C=CCN
# Starting OPT
# Execution time OPT: 37s
# There are 11 atoms and 50 MOs
# computing dft for CC(N)CCCO
# Starting OPT
# Execution time OPT: 92s
# There are 20 atoms and 89 MOs
# computing dft for NC=CNOO
# Starting OPT
# Execution time OPT: 126s
# There are 12 atoms and 66 MOs
# homo_mean : -5.84942
# homo_med : -5.62119
# homo_std : 0.98712
# homo_min : -10.58115
# homo_max : -3.92062
# lumo_mean : 2.12510
# lumo_med : 2.54236
# lumo_std : 1.06571
# lumo_min : -2.91380
# lumo_max : 3.97014
# gap_mean : 7.97452
# gap_med : 8.07892
# gap_std : 1.34330
# gap_min : 3.51027
# gap_max : 14.55129
# total_mean : -5.84942
# total_med : -5.62119
# total_std : 0.98712
# total_min : -10.58115
# total_max : -3.92062
# new step
# step : 20
# best : NC1=CNCC1O
# computing dft for NC1(O)CNC=C1F
# Starting OPT
# Execution time OPT: 83s
# There are 15 atoms and 86 MOs
# computing dft for COC#CN
# Starting OPT
# Execution time OPT: 43s
# There are 10 atoms and 55 MOs
# computing dft for COCC=CN
# Starting OPT
# Execution time OPT: 76s
# There are 15 atoms and 72 MOs
# computing dft for CC(O)CCNO
# Starting OPT
# Execution time OPT: 121s
# There are 18 atoms and 85 MOs
# computing dft for NC1=CNC(N)C1
# Starting OPT
# Execution time OPT: 97s
# There are 16 atoms and 81 MOs
# computing dft for C=CC=C(N)CF
# Starting OPT
# Execution time OPT: 97s
# There are 15 atoms and 79 MOs
# computing dft for NONC1(N)CNN1
# Starting OPT
# Execution time OPT: 222s
# There are 17 atoms and 90 MOs
# computing dft for NCC1=CC1
# Starting OPT
# Execution time OPT: 61s
# There are 12 atoms and 59 MOs
# computing dft for NC1=CN1OO
# Starting OPT
# Execution time OPT: 108s
# There are 10 atoms and 62 MOs
# computing dft for CCC=C(N)N
# MM error (Evaluation error)
# computing dft for C=CN
# Starting OPT
# Execution time OPT: 17s
# There are 8 atoms and 37 MOs
# homo_mean : -5.80646
# homo_med : -5.60963
# homo_std : 0.97963
# homo_min : -10.58115
# homo_max : -3.90157
# lumo_mean : 2.07098
# lumo_med : 2.42930
# lumo_std : 1.06700
# lumo_min : -2.91380
# lumo_max : 3.97014
# gap_mean : 7.87744
# gap_med : 8.03362
# gap_std : 1.36473
# gap_min : 3.51027
# gap_max : 14.55129
# total_mean : -5.80646
# total_med : -5.60963
# total_std : 0.97963
# total_min : -10.58115
# total_max : -3.90157
# new step
# step : 21
# best : NC1=CNC(N)C1
# computing dft for NNC1=CNC(N)CC1
# Starting OPT
# Execution time OPT: 148s
# There are 21 atoms and 105 MOs
# computing dft for NC1CC2NC2C1O
# Starting OPT
# Execution time OPT: 173s
# There are 18 atoms and 92 MOs
# computing dft for CC(N)OC=CF
# Starting OPT
# Execution time OPT: 162s
# There are 15 atoms and 79 MOs
# computing dft for COC=C=N
# MM error (Evaluation error)
# computing dft for CC(N)=CN
# Starting OPT
# Execution time OPT: 79s
# There are 13 atoms and 61 MOs
# computing dft for NC1=CN2C(N)C12OF
# Starting OPT
# Execution time OPT: 162s
# There are 15 atoms and 93 MOs
# computing dft for C=CC
# Starting OPT
# Execution time OPT: 11s
# There are 9 atoms and 39 MOs
# computing dft for NCNN(N)CN
# Starting OPT
# Execution time OPT: 214s
# There are 18 atoms and 85 MOs
# computing dft for CC=CNF
# Starting OPT
# Execution time OPT: 37s
# There are 11 atoms and 57 MOs
# computing dft for NC=C(N)OO
# Starting OPT
# Execution time OPT: 116s
# There are 12 atoms and 66 MOs
# computing dft for CCC=C(N)N
# MM error (Evaluation error)
# computing dft for CC=CC
# Starting OPT
# Execution time OPT: 11s
# There are 12 atoms and 52 MOs
# homo_mean : -5.77494
# homo_med : -5.59384
# homo_std : 0.98589
# homo_min : -10.58115
# homo_max : -3.90157
# lumo_mean : 1.98992
# lumo_med : 2.37025
# lumo_std : 1.13581
# lumo_min : -2.91380
# lumo_max : 3.97014
# gap_mean : 7.76486
# gap_med : 7.92137
# gap_std : 1.45744
# gap_min : 2.43025
# gap_max : 14.55129
# total_mean : -5.77494
# total_med : -5.59384
# total_std : 0.98589
# total_min : -10.58115
# total_max : -3.90157
# new step
# step : 22
# best : NC1=CNC(N)C1
# computing dft for NN1C=C2CC1N2
# MM error (Evaluation error)
# computing dft for CN1C=C(N)C(O)C1
# Starting OPT
# Execution time OPT: 318s
# There are 18 atoms and 92 MOs
# computing dft for NC=C1C=N1
# MM error (Evaluation error)
# computing dft for COC1=CN1
# MM error (Evaluation error)
# computing dft for NN=C(NO)OO
# Starting OPT
# Execution time OPT: 218s
# There are 12 atoms and 73 MOs
# computing dft for NC1CC(NO)=CN1
# Starting OPT
# Execution time OPT: 303s
# There are 17 atoms and 90 MOs
# computing dft for C=COC
# Starting OPT
# Execution time OPT: 45s
# There are 10 atoms and 48 MOs
# computing dft for CC(C)=CN
# Starting OPT
# Execution time OPT: 83s
# There are 14 atoms and 63 MOs
# computing dft for NC1=NCC(N)C1O
# MM error (Evaluation error)
# computing dft for C=C=CC
# Starting OPT
# Execution time OPT: 24s
# There are 10 atoms and 48 MOs
# computing dft for NNCC1(N)NC1N
# Starting OPT
# Execution time OPT: 113s
# There are 19 atoms and 94 MOs
# computing dft for CC=CNC
# MM error (Evaluation error)
# computing dft for CC(N)=CNOO
# Starting OPT
# Execution time OPT: 298s
# There are 15 atoms and 79 MOs
# computing dft for CCC(N)=CN
# Starting OPT
# Execution time OPT: 196s
# There are 16 atoms and 74 MOs
# computing dft for C1=CN=CC1
# Starting OPT
# Execution time OPT: 25s
# There are 10 atoms and 55 MOs
# homo_mean : -5.74872
# homo_med : -5.58146
# homo_std : 0.98766
# homo_min : -10.58115
# homo_max : -3.90157
# lumo_mean : 1.93269
# lumo_med : 2.32644
# lumo_std : 1.15886
# lumo_min : -2.91380
# lumo_max : 3.97014
# gap_mean : 7.68140
# gap_med : 7.82790
# gap_std : 1.47189
# gap_min : 2.43025
# gap_max : 14.55129
# total_mean : -5.74872
# total_med : -5.58146
# total_std : 0.98766
# total_min : -10.58115
# total_max : -3.90157
# new step
# step : 23
# best : NC1=CNC(N)C1
# computing dft for NC1=C2NC(C1)N2
# MM error (Evaluation error)
# computing dft for NC1=C(O)NCC1O
# Starting OPT
# Execution time OPT: 123s
# There are 16 atoms and 88 MOs
# computing dft for CCC1=CN=N1
# Starting OPT
# Execution time OPT: 62s
# There are 12 atoms and 66 MOs
# computing dft for CC(C)C(N)=CN
# Starting OPT
# Execution time OPT: 292s
# There are 19 atoms and 87 MOs
# computing dft for NCON
# Starting OPT
# Execution time OPT: 51s
# There are 10 atoms and 48 MOs
# computing dft for NC=COO
# Starting OPT
# Execution time OPT: 67s
# There are 10 atoms and 55 MOs
# computing dft for NNC1=CNCCC1N
# Starting OPT
# Execution time OPT: 137s
# There are 21 atoms and 105 MOs
# computing dft for CN1C=C(N)CC1O
# Starting OPT
# Execution time OPT: 171s
# There are 18 atoms and 92 MOs
# computing dft for CCOC=CN
# Starting OPT
# Execution time OPT: 79s
# There are 15 atoms and 72 MOs
# computing dft for NC1CC(NO)N1
# Starting OPT
# Execution time OPT: 266s
# There are 16 atoms and 81 MOs
# computing dft for OC=CO
# Starting OPT
# Execution time OPT: 25s
# There are 8 atoms and 44 MOs
# homo_mean : -5.70478
# homo_med : -5.57330
# homo_std : 0.99441
# homo_min : -10.58115
# homo_max : -3.90157
# lumo_mean : 1.89518
# lumo_med : 2.28616
# lumo_std : 1.18463
# lumo_min : -2.91380
# lumo_max : 3.97014
# gap_mean : 7.59996
# gap_med : 7.75048
# gap_std : 1.49630
# gap_min : 2.43025
# gap_max : 14.55129
# total_mean : -5.70478
# total_med : -5.57330
# total_std : 0.99441
# total_min : -10.58115
# total_max : -3.90157
# new step
# step : 24
# best : NC1=CNC(N)C1
# computing dft for CN1C=CCC1N
# Starting OPT
# Execution time OPT: 147s
# There are 17 atoms and 83 MOs
# computing dft for NC=C(CN)CO
# Starting OPT
# Execution time OPT: 127s
# There are 17 atoms and 83 MOs
# computing dft for CN1C=C(N)C1OO
# Starting OPT
# Execution time OPT: 116s
# There are 16 atoms and 88 MOs
# computing dft for CC1NC1=CN
# Starting OPT
# Execution time OPT: 290s
# There are 14 atoms and 70 MOs
# computing dft for CC(C)N=CN
# MM error (Evaluation error)
# computing dft for NNC1=CCCC1N
# Starting OPT
# Execution time OPT: 360s
# There are 19 atoms and 94 MOs
# computing dft for C1=COCN1
# Starting OPT
# Execution time OPT: 57s
# There are 10 atoms and 55 MOs
# computing dft for NC=C(N)O
# Starting OPT
# Execution time OPT: 60s
# There are 11 atoms and 57 MOs
# computing dft for NNC1C=CNC(N)C1
# Starting OPT
# Execution time OPT: 151s
# There are 21 atoms and 105 MOs
# computing dft for CN(C)C=C(N)CF
# Starting OPT
# Execution time OPT: 186s
# There are 19 atoms and 94 MOs
# computing dft for CC(F)OC=C(N)O
# Starting OPT
# Execution time OPT: 98s
# There are 16 atoms and 88 MOs
# homo_mean : -5.65201
# homo_med : -5.53031
# homo_std : 0.99668
# homo_min : -10.58115
# homo_max : -3.90157
# lumo_mean : 1.87100
# lumo_med : 2.17310
# lumo_std : 1.16861
# lumo_min : -2.91380
# lumo_max : 3.97014
# gap_mean : 7.52301
# gap_med : 7.70395
# gap_std : 1.50380
# gap_min : 2.43025
# gap_max : 14.55129
# total_mean : -5.65201
# total_med : -5.53031
# total_std : 0.99668
# total_min : -10.58115
# total_max : -3.90157
# new step
# step : 25
# best : NC1=CNC(N)C1
# computing dft for NC1=CCC(N)C1
# Starting OPT
# Execution time OPT: 113s
# There are 17 atoms and 83 MOs
# computing dft for OC1Cn2cc1[nH]2
# MM error (Evaluation error)
# computing dft for CN1CCC1N
# Starting OPT
# Execution time OPT: 123s
# There are 16 atoms and 74 MOs
# computing dft for CCC(N)CCN
# Starting OPT
# Execution time OPT: 113s
# There are 21 atoms and 91 MOs
# computing dft for NCC=NN
# Starting OPT
# Execution time OPT: 54s
# There are 12 atoms and 59 MOs
# computing dft for NNC1=CNC#CC1N
# MM error (Evaluation error)
# computing dft for NC=COCCN
# Starting OPT
# Execution time OPT: 124s
# There are 17 atoms and 83 MOs
# computing dft for NCC=C(N)OO
# Starting OPT

# %%
# Running 10 executions

# for i in range(10):
#     run(i)
